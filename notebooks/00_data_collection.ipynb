# %% [markdown]
# # 00 — Obtención de los datos
#
# Este notebook documentará el origen del dataset y permitirá reproducir su obtención.

# %% [markdown]
# ## Preguntas a responder
#
# - ¿De dónde provienen los datos y bajo qué licencia pueden utilizarse?
# - ¿Qué representa cada observación?
# - ¿Qué período y población cubre el dataset?
# - ¿Qué filtros o transformaciones se aplicaron durante la obtención?
# - ¿Cómo puede otra persona reproducir la descarga?

# %% [markdown]
# ## Resultado esperado
#
# Guardar los datos originales sin modificaciones en `data/raw` y registrar su procedencia.
