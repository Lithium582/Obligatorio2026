# %% [markdown]
# # 01 — Análisis exploratorio de datos
#
# Este notebook analiza los datasets originales de reservas de los dos hoteles. En esta primera etapa se configura el entorno, se cargan los archivos y se valida que ambos compartan el mismo esquema.

# %% [markdown]
# ## Configuración del entorno
#
# La resolución de la raíz permite ejecutar el notebook tanto desde la raíz del repositorio como desde la carpeta `notebooks`. Si el repositorio no está disponible localmente, la carga puede utilizar las URL Raw de GitHub configuradas más adelante.

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_theme(style="whitegrid")

# Fuerzo a Pandas a mostrar todas las columnas del Dataset
pd.set_option("display.max_columns", None)

# %%
def find_project_root(start_path=None):
    """Busca la raíz del repositorio a partir del directorio actual."""
    start = Path(start_path or Path.cwd()).resolve()

    for candidate in [start, *start.parents]:
        if (candidate / "data" / "raw").is_dir():
            return candidate

    return None


PROJECT_ROOT = find_project_root()
RAW_DATA_DIR = PROJECT_ROOT / "data" / "raw" if PROJECT_ROOT else None

print(f"Raíz del proyecto: {PROJECT_ROOT or 'no disponible localmente'}")
# Out:
# Raíz del proyecto: C:\Code\Vialesoft\Vialesoft_Devlab\Mini_Proyectos\Machine_Learning\Obligatorio2026

# %%
if PROJECT_ROOT is not None:
    project_root_str = str(PROJECT_ROOT)

    if project_root_str not in sys.path:
        sys.path.insert(0, project_root_str)

# %% [markdown]
# ## Carga de los datasets
#
# La carga prioriza los archivos originales disponibles en `data/raw`. Si no los encuentra, utiliza las URL Raw de GitHub. De esta forma, el mismo notebook podrá ejecutarse dentro del repositorio o en un entorno remoto como Google Colab.

# %%
from src.data import load_csv

load_from_URL = True  # Cambiar a False si se desea cargar desde archivos locales

# Defino las URLs de los datasets H1 y H2
H1_URL = "https://raw.githubusercontent.com/Lithium582/Obligatorio2026/refs/heads/main/data/raw/H1.csv"  # Completar con la URL Raw de H1.csv
H2_URL = "https://raw.githubusercontent.com/Lithium582/Obligatorio2026/refs/heads/main/data/raw/H2.csv"  # Completar con la URL Raw de H2.csv

# Defino las rutas locales de los datasets H1 y H2
H1_LOCAL_PATH = RAW_DATA_DIR / "H1.csv" if RAW_DATA_DIR else None
H2_LOCAL_PATH = RAW_DATA_DIR / "H2.csv" if RAW_DATA_DIR else None

if load_from_URL:
    h1_df = load_csv(H1_URL)
    h2_df = load_csv(H2_URL)
else:
    h1_df = load_csv(H1_LOCAL_PATH)
    h2_df = load_csv(H2_LOCAL_PATH)

print(f"H1 cargado")
print(f"H2 cargado")
# Out:
# H1 cargado
# H2 cargado

# %% [markdown]
# ## Validación del esquema
#
# Antes de integrar los hoteles se comprueba que ambos archivos contengan las mismas columnas y en el mismo orden.

# %%
h1_columns = list(h1_df.columns)
h2_columns = list(h2_df.columns)

if h1_columns != h2_columns:
    only_in_h1 = sorted(set(h1_columns) - set(h2_columns))
    only_in_h2 = sorted(set(h2_columns) - set(h1_columns))
    raise ValueError(
        "Los datasets no comparten el mismo esquema. "
        f"Sólo en H1: {only_in_h1}. Sólo en H2: {only_in_h2}."
    )

schema_summary = pd.DataFrame(
    {
        "dataset": ["H1", "H2"],
        "rows": [len(h1_df), len(h2_df)],
        "columns": [len(h1_columns), len(h2_columns)],
        "shared_schema": [True, True],
    }
)

display(schema_summary)
display(pd.DataFrame({"column": h1_columns}))
# Out:
#   dataset   rows  columns  shared_schema
# 0      H1  40060       31           True
# 1      H2  79330       31           True
#                          column
# 0                    IsCanceled
# 1                      LeadTime
# 2               ArrivalDateYear
# 3              ArrivalDateMonth
# 4         ArrivalDateWeekNumber
# 5         ArrivalDateDayOfMonth
# 6          StaysInWeekendNights
# 7             StaysInWeekNights
# 8                        Adults
# 9                      Children
# 10                       Babies
# 11                         Meal
# 12                      Country
# 13                MarketSegment
# 14          DistributionChannel
# 15              IsRepeatedGuest
# 16        PreviousCancellations
# 17  PreviousBookingsNotCanceled
# 18             ReservedRoomType
# 19             AssignedRoomType
# 20               BookingChanges
# 21                  DepositType
# 22                        Agent
# 23                      Company
# 24            DaysInWaitingList
# 25                 CustomerType
# 26                          ADR
# 27     RequiredCarParkingSpaces
# 28       TotalOfSpecialRequests
# 29            ReservationStatus
# 30        ReservationStatusDate

# %% [markdown]
# ## Integración de los datasets
#
# Antes de concatenar los archivos se agrega `HotelType` para conservar el origen de cada reserva. Esta variable distingue los dos hoteles observados, pero no debe interpretarse como una comparación general entre todos los resort hotels y city hotels.

# %%
h1_with_hotel = h1_df.copy()
h2_with_hotel = h2_df.copy()

h1_with_hotel.insert(0, "HotelType", "Resort Hotel")
h2_with_hotel.insert(0, "HotelType", "City Hotel")

bookings_df = pd.concat(
    [h1_with_hotel, h2_with_hotel],
    ignore_index=True,
)

# %% [markdown]
# ### Validación de la integración
#
# Se comprueba que la concatenación conserve todas las reservas y que cada dataset haya recibido el identificador esperado.

# %%
expected_rows = len(h1_df) + len(h2_df)
expected_hotel_types = {"Resort Hotel", "City Hotel"}
observed_hotel_types = set(bookings_df["HotelType"].unique())

if len(bookings_df) != expected_rows:
    raise ValueError(
        f"La integración produjo {len(bookings_df)} filas; "
        f"se esperaban {expected_rows}."
    )

if observed_hotel_types != expected_hotel_types:
    raise ValueError(
        "Los identificadores de hotel no coinciden con los esperados: "
        f"{sorted(observed_hotel_types)}."
    )

integration_summary = (
    bookings_df.groupby("HotelType", as_index=False)
    .size()
    .rename(columns={"size": "rows"})
)

display(integration_summary)
display(bookings_df.head())
print(f"Dataset integrado: {bookings_df.shape[0]} filas y {bookings_df.shape[1]} columnas.")
# Out:
#       HotelType   rows
# 0    City Hotel  79330
# 1  Resort Hotel  40060
#       HotelType  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0  Resort Hotel           0       342             2015             July
# 1  Resort Hotel           0       737             2015             July
# 2  Resort Hotel           0         7             2015             July
# 3  Resort Hotel           0        13             2015             July
# 4  Resort Hotel           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 0                  0       2       0.0       0  BB            PRT
# 1                  0       2       0.0       0  BB            PRT
# 2                  1       1       0.0       0  BB            GBR
# 3                  1       1       0.0       0  BB            GBR
# 4                  2       2       0.0       0  BB            GBR
#
#   MarketSegment DistributionChannel  IsRepeatedGuest  PreviousCancellations  \
# 0        Direct              Direct                0                      0
# 1        Direct              Direct                0                      0
# 2        Direct              Direct                0                      0
# 3     Corporate           Corporate                0                      0
# 4     Online TA               TA/TO                0                      0
#
#    PreviousBookingsNotCanceled  ReservedRoomType  AssignedRoomType  \
# 0                            0  C                 C
# 1                            0  C                 C
# 2                            0  A                 C
# 3                            0  A                 A
# 4                            0  A                 A
#
#    BookingChanges      DepositType        Agent      Company  \
# 0               3  No Deposit              NULL         NULL
# 1               4  No Deposit              NULL         NULL
# 2               0  No Deposit              NULL         NULL
# 3               0  No Deposit               304         NULL
# 4               0  No Deposit               240         NULL
#
#    DaysInWaitingList CustomerType   ADR  RequiredCarParkingSpaces  \
# 0                  0    Transient   0.0                         0
# 1                  0    Transient   0.0                         0
# 2                  0    Transient  75.0                         0
# 3                  0    Transient  75.0                         0
# 4                  0    Transient  98.0                         0
#
#    TotalOfSpecialRequests ReservationStatus ReservationStatusDate
# 0                       0         Check-Out            2015-07-01
# 1                       0         Check-Out            2015-07-01
# 2                       0         Check-Out            2015-07-02
# 3                       0         Check-Out            2015-07-02
# 4                       1         Check-Out            2015-07-03
# Dataset integrado: 119390 filas y 32 columnas.

# %% [markdown]
# ## EDA Inicial

# %% [markdown]
# ### Búsqueda de nulos
#
# Este dataset tiene algunas particularidades
# Por ejemplo, muchas columnas tienen el valor "NULL" escrito como texto (esto se ve en el "head", en columnas como "Company"), por lo que como primer paso para limpiarlo debemos eliminar espacios de relleno y después convertir estos textos "NULL" a valores nulos

# %%
bookings_df.describe()
# Out:
#           IsCanceled       LeadTime  ArrivalDateYear  ArrivalDateWeekNumber  \
# count  119390.000000  119390.000000    119390.000000          119390.000000
# mean        0.370416     104.011416      2016.156554              27.165173
# std         0.482918     106.863097         0.707476              13.605138
# min         0.000000       0.000000      2015.000000               1.000000
# 25%         0.000000      18.000000      2016.000000              16.000000
# 50%         0.000000      69.000000      2016.000000              28.000000
# 75%         1.000000     160.000000      2017.000000              38.000000
# max         1.000000     737.000000      2017.000000              53.000000
#
#        ArrivalDateDayOfMonth  StaysInWeekendNights  StaysInWeekNights  \
# count          119390.000000         119390.000000      119390.000000
# mean               15.798241              0.927599           2.500302
# std                 8.780829              0.998613           1.908286
# min                 1.000000              0.000000           0.000000
# 25%                 8.000000              0.000000           1.000000
# 50%                16.000000              1.000000           2.000000
# 75%                23.000000              2.000000           3.000000
# max                31.000000             19.000000          50.000000
#
#               Adults       Children         Babies  IsRepeatedGuest  \
# count  119390.000000  119386.000000  119390.000000    119390.000000
# mean        1.856403       0.103890       0.007949         0.031912
# std         0.579261       0.398561       0.097436         0.175767
# min         0.000000       0.000000       0.000000         0.000000
# 25%         2.000000       0.000000       0.000000         0.000000
# 50%         2.000000       0.000000       0.000000         0.000000
# 75%         2.000000       0.000000       0.000000         0.000000
# max        55.000000      10.000000      10.000000         1.000000
#
#        PreviousCancellations  PreviousBookingsNotCanceled  BookingChanges  \
# count          119390.000000                119390.000000   119390.000000
# mean                0.087118                     0.137097        0.221124
# std                 0.844336                     1.497437        0.652306
# min                 0.000000                     0.000000        0.000000
# 25%                 0.000000                     0.000000        0.000000
# 50%                 0.000000                     0.000000        0.000000
# 75%                 0.000000                     0.000000        0.000000
# max                26.000000                    72.000000       21.000000
#
#        DaysInWaitingList            ADR  RequiredCarParkingSpaces  \
# count      119390.000000  119390.000000             119390.000000
# mean            2.321149     101.831122                  0.062518
# std            17.594721      50.535790                  0.245291
# min             0.000000      -6.380000                  0.000000
# 25%             0.000000      69.290000                  0.000000
# 50%             0.000000      94.575000                  0.000000
# 75%             0.000000     126.000000                  0.000000
# max           391.000000    5400.000000                  8.000000
#
#        TotalOfSpecialRequests
# count           119390.000000
# mean                 0.571363
# std                  0.792798
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  1.000000
# max                  5.000000

# %%
null_counts = bookings_df.isna().sum()
null_counts[null_counts > 0].sort_values(ascending=False)
# Out:
# Country     488
# Children      4
# dtype: int64

# %%
text_columns = bookings_df.select_dtypes(include=["object", "string"]).columns

# Elimino los espacios de relleno sin alterar los nulos ya reconocidos.
bookings_df[text_columns] = bookings_df[text_columns].apply(
    lambda column: column.str.strip()
)

# Convierto la categoría textual NULL en un valor nulo real de pandas.
bookings_df[text_columns] = bookings_df[text_columns].replace("NULL", pd.NA)

# %%
null_counts = bookings_df.isna().sum()
null_counts[null_counts > 0].sort_values(ascending=False)
# Out:
# Company     112593
# Agent        16340
# Country        488
# Children         4
# dtype: int64

# %% [markdown]
# ### Búsqueda de etiquetas especiales
#
# Además de los nulos reconocidos por pandas, se buscan categorías que podrían representar información ausente o no definida. La coincidencia es exacta y no distingue mayúsculas, minúsculas ni espacios exteriores. Encontrar una etiqueta no implica que deba imputarse: primero debe interpretarse según el significado de la columna.

# %%
special_missing_labels = {
    "NA",
    "N/A",
    "N.A.",
    "NONE",
    "NULL",
    "NAN",
    "UNKNOWN",
    "UNDEFINED",
    "NOT APPLICABLE",
    "NOT AVAILABLE",
    "MISSING",
    "?",
}

special_label_records = []

for column in text_columns:
    normalized_values = (
        bookings_df[column]
        .astype("string")
        .str.strip()
        .str.upper()
    )
    label_counts = normalized_values[
        normalized_values.isin(special_missing_labels)
    ].value_counts()

    for label, count in label_counts.items():
        special_label_records.append(
            {
                "column": column,
                "label": label,
                "count": count,
                "percentage": count / len(bookings_df) * 100,
            }
        )

special_labels_summary = pd.DataFrame(special_label_records)

if special_labels_summary.empty:
    print("No se encontraron etiquetas especiales adicionales.")
else:
    display(
        special_labels_summary.sort_values("count", ascending=False)
        .reset_index(drop=True)
    )
# Out:
#                 column      label  count  percentage
# 0                 Meal  UNDEFINED   1169    0.979144
# 1  DistributionChannel  UNDEFINED      5    0.004188
# 2        MarketSegment  UNDEFINED      2    0.001675

# %% [markdown]
# ### Reservas sin huéspedes o sin noches
#
# Se buscan reservas cuya composición completa de huéspedes suma cero y reservas que no registran noches de estadía. Para identificar reservas sin personas se exige que `Adults`, `Children` y `Babies` estén informadas; un nulo no se interpreta como cero.

# %%
guest_columns = ["Adults", "Children", "Babies"]
night_columns = ["StaysInWeekendNights", "StaysInWeekNights"]

total_guests = bookings_df[guest_columns].sum(
    axis=1,
    min_count=len(guest_columns),
)
total_nights = bookings_df[night_columns].sum(axis=1)

no_guests_mask = total_guests.eq(0)
zero_nights_mask = total_nights.eq(0)

particular_cases_summary = pd.DataFrame(
    {
        "case": [
            "No guests",
            "Zero nights",
            "No guests and zero nights",
        ],
        "rows": [
            no_guests_mask.sum(),
            zero_nights_mask.sum(),
            (no_guests_mask & zero_nights_mask).sum(),
        ],
    }
)
particular_cases_summary["percentage"] = (
    particular_cases_summary["rows"] / len(bookings_df) * 100
)

display(particular_cases_summary)
# Out:
#                         case  rows  percentage
# 0                  No guests   180    0.150766
# 1                Zero nights   715    0.598878
# 2  No guests and zero nights    70    0.058631

# %%
display(
    bookings_df.loc[
        no_guests_mask,
        ["HotelType", *guest_columns, *night_columns, "IsCanceled"],
    ].head(20)
)

display(
    bookings_df.loc[
        zero_nights_mask,
        ["HotelType", *guest_columns, *night_columns, "IsCanceled"],
    ].head(20)
)
# Out:
#           HotelType  Adults  Children  Babies  StaysInWeekendNights  \
# 2224   Resort Hotel       0       0.0       0                     0
# 2409   Resort Hotel       0       0.0       0                     0
# 3181   Resort Hotel       0       0.0       0                     1
# 3684   Resort Hotel       0       0.0       0                     1
# 3708   Resort Hotel       0       0.0       0                     2
# 4127   Resort Hotel       0       0.0       0                     0
# 9376   Resort Hotel       0       0.0       0                     0
# 31765  Resort Hotel       0       0.0       0                     2
# 32029  Resort Hotel       0       0.0       0                     0
# 32827  Resort Hotel       0       0.0       0                     3
# 34849  Resort Hotel       0       0.0       0                     2
# 34855  Resort Hotel       0       0.0       0                     2
# 37459  Resort Hotel       0       0.0       0                     2
# 40392    City Hotel       0       0.0       0                     2
# 40922    City Hotel       0       0.0       0                     2
# 41020    City Hotel       0       0.0       0                     9
# 41056    City Hotel       0       0.0       0                     0
# 42452    City Hotel       0       0.0       0                     2
# 42591    City Hotel       0       0.0       0                     1
# 42871    City Hotel       0       0.0       0                     0
#
#        StaysInWeekNights  IsCanceled
# 2224                   3           0
# 2409                   0           0
# 3181                   2           0
# 3684                   4           0
# 3708                   4           0
# 4127                   0           1
# 9376                   0           1
# 31765                  8           0
# 32029                  1           0
# 32827                  9           0
# 34849                  6           0
# 34855                  6           0
# 37459                  5           0
# 40392                  5           0
# 40922                  0           0
# 41020                 20           0
# 41056                  4           0
# 42452                  0           1
# 42591                  4           0
# 42871                  2           0
#         HotelType  Adults  Children  Babies  StaysInWeekendNights  \
# 0    Resort Hotel       2       0.0       0                     0
# 1    Resort Hotel       2       0.0       0                     0
# 167  Resort Hotel       2       0.0       0                     0
# 168  Resort Hotel       1       0.0       0                     0
# 196  Resort Hotel       2       0.0       0                     0
# 197  Resort Hotel       2       0.0       0                     0
# 459  Resort Hotel       2       0.0       0                     0
# 568  Resort Hotel       1       0.0       0                     0
# 569  Resort Hotel       2       0.0       0                     0
# 618  Resort Hotel       2       2.0       0                     0
# 619  Resort Hotel       2       0.0       0                     0
# 665  Resort Hotel       2       1.0       0                     0
# 722  Resort Hotel       2       0.0       0                     0
# 774  Resort Hotel       2       0.0       0                     0
# 814  Resort Hotel       1       0.0       0                     0
# 815  Resort Hotel       2       0.0       0                     0
# 882  Resort Hotel       2       2.0       0                     0
# 893  Resort Hotel       2       0.0       0                     0
# 894  Resort Hotel       2       0.0       0                     0
# 907  Resort Hotel       3       0.0       0                     0
#
#      StaysInWeekNights  IsCanceled
# 0                    0           0
# 1                    0           0
# 167                  0           0
# 168                  0           0
# 196                  0           0
# 197                  0           0
# 459                  0           0
# 568                  0           0
# 569                  0           0
# 618                  0           0
# 619                  0           0
# 665                  0           0
# 722                  0           0
# 774                  0           0
# 814                  0           0
# 815                  0           0
# 882                  0           0
# 893                  0           0
# 894                  0           0
# 907                  0           0

# %% [markdown]
# Estas observaciones se mantienen por ahora. Su tratamiento se decidirá después de estudiar si representan errores, cancelaciones administrativas, reservas de uso diurno u otras situaciones válidas del negocio.

# %% [markdown]
# ## Análisis de valores únicos y categorías
#
# La cardinalidad permite distinguir variables categóricas manejables, identificadores y variables numéricas continuas o discretas. En esta etapa sólo se describen los valores observados: una categoría poco frecuente no se considera errónea automáticamente.

# %%
unique_values_summary = pd.DataFrame(
    {
        "dtype": bookings_df.dtypes.astype(str),
        "non_null_rows": bookings_df.notna().sum(),
        "null_rows": bookings_df.isna().sum(),
        "unique_values": bookings_df.nunique(dropna=True),
    }
).sort_values(["unique_values", "null_rows"])

display(unique_values_summary)
# Out:
#                                dtype  non_null_rows  null_rows  unique_values
# HotelType                        str         119390          0              2
# IsCanceled                     int64         119390          0              2
# IsRepeatedGuest                int64         119390          0              2
# ArrivalDateYear                int64         119390          0              3
# DepositType                      str         119390          0              3
# ReservationStatus                str         119390          0              3
# CustomerType                     str         119390          0              4
# Babies                         int64         119390          0              5
# Meal                             str         119390          0              5
# DistributionChannel              str         119390          0              5
# RequiredCarParkingSpaces       int64         119390          0              5
# Children                     float64         119386          4              5
# TotalOfSpecialRequests         int64         119390          0              6
# MarketSegment                    str         119390          0              8
# ReservedRoomType                 str         119390          0             10
# ArrivalDateMonth                 str         119390          0             12
# AssignedRoomType                 str         119390          0             12
# Adults                         int64         119390          0             14
# PreviousCancellations          int64         119390          0             15
# StaysInWeekendNights           int64         119390          0             17
# BookingChanges                 int64         119390          0             21
# ArrivalDateDayOfMonth          int64         119390          0             31
# StaysInWeekNights              int64         119390          0             35
# ArrivalDateWeekNumber          int64         119390          0             53
# PreviousBookingsNotCanceled    int64         119390          0             73
# DaysInWaitingList              int64         119390          0            128
# Country                          str         118902        488            177
# Agent                            str         103050      16340            333
# Company                          str           6797     112593            352
# LeadTime                       int64         119390          0            479
# ReservationStatusDate            str         119390          0            926
# ADR                          float64         119390          0           8879

# %% [markdown]
# ### Distribución de las variables categóricas
#
# Se muestran todas las categorías junto con su frecuencia y porcentaje. Los nulos se presentan explícitamente para no confundirlos con categorías de baja frecuencia.

# %%
categorical_columns = bookings_df.select_dtypes(
    include=["object", "string", "category"]
).columns.tolist()

for column in categorical_columns:
    category_counts = (
        bookings_df[column]
        .value_counts(dropna=False)
        .rename_axis(column)
        .reset_index(name="rows")
    )
    category_counts["percentage"] = (
        category_counts["rows"] / len(bookings_df) * 100
    )

    print(f"{column}: {bookings_df[column].nunique(dropna=True)} categorías no nulas")
    display(category_counts)
# Out:
# HotelType: 2 categorías no nulas
#       HotelType   rows  percentage
# 0    City Hotel  79330   66.446101
# 1  Resort Hotel  40060   33.553899
# ArrivalDateMonth: 12 categorías no nulas
#    ArrivalDateMonth   rows  percentage
# 0            August  13877   11.623252
# 1              July  12661   10.604741
# 2               May  11791    9.876037
# 3           October  11160    9.347517
# 4             April  11089    9.288048
# 5              June  10939    9.162409
# 6         September  10508    8.801407
# 7             March   9794    8.203367
# 8          February   8068    6.757685
# 9          November   6794    5.690594
# 10         December   6780    5.678868
# 11          January   5929    4.966078
# Meal: 5 categorías no nulas
#         Meal   rows  percentage
# 0         BB  92310   77.318033
# 1         HB  14463   12.114080
# 2         SC  10650    8.920345
# 3  Undefined   1169    0.979144
# 4         FB    798    0.668398
# Country: 177 categorías no nulas
#     Country   rows  percentage
# 0       PRT  48590   40.698551
# 1       GBR  12129   10.159142
# 2       FRA  10415    8.723511
# 3       ESP   8568    7.176480
# 4       DEU   7287    6.103526
# ..      ...    ...         ...
# 173     NCL      1    0.000838
# 174     KIR      1    0.000838
# 175     SDN      1    0.000838
# 176     ATF      1    0.000838
# 177     SLE      1    0.000838
#
# [178 rows x 3 columns]
# MarketSegment: 8 categorías no nulas
#    MarketSegment   rows  percentage
# 0      Online TA  56477   47.304632
# 1  Offline TA/TO  24219   20.285619
# 2         Groups  19811   16.593517
# 3         Direct  12606   10.558673
# 4      Corporate   5295    4.435045
# 5  Complementary    743    0.622330
# 6       Aviation    237    0.198509
# 7      Undefined      2    0.001675
# DistributionChannel: 5 categorías no nulas
#   DistributionChannel   rows  percentage
# 0               TA/TO  97870   81.975040
# 1              Direct  14645   12.266521
# 2           Corporate   6677    5.592596
# 3                 GDS    193    0.161655
# 4           Undefined      5    0.004188
# ReservedRoomType: 10 categorías no nulas
#   ReservedRoomType   rows  percentage
# 0                A  85994   72.027808
# 1                D  19201   16.082586
# 2                E   6535    5.473658
# 3                F   2897    2.426501
# 4                G   2094    1.753916
# 5                B   1118    0.936427
# 6                C    932    0.780635
# 7                H    601    0.503392
# 8                P     12    0.010051
# 9                L      6    0.005026
# AssignedRoomType: 12 categorías no nulas
#    AssignedRoomType   rows  percentage
# 0                 A  74053   62.026133
# 1                 D  25322   21.209482
# 2                 E   7806    6.538236
# 3                 F   3751    3.141804
# 4                 G   2553    2.138370
# 5                 C   2375    1.989279
# 6                 B   2163    1.811710
# 7                 H    712    0.596365
# 8                 I    363    0.304046
# 9                 K    279    0.233688
# 10                P     12    0.010051
# 11                L      1    0.000838
# DepositType: 3 categorías no nulas
#   DepositType    rows  percentage
# 0  No Deposit  104641   87.646369
# 1  Non Refund   14587   12.217941
# 2  Refundable     162    0.135690
# Agent: 333 categorías no nulas
#     Agent   rows  percentage
# 0       9  31961   26.770249
# 1     NaN  16340   13.686238
# 2     240  13922   11.660943
# 3       1   7191    6.023118
# 4      14   3640    3.048832
# ..    ...    ...         ...
# 329   444      1    0.000838
# 330   408      1    0.000838
# 331   388      1    0.000838
# 332   453      1    0.000838
# 333   480      1    0.000838
#
# [334 rows x 3 columns]
# Company: 352 categorías no nulas
#     Company    rows  percentage
# 0       NaN  112593   94.306893
# 1        40     927    0.776447
# 2       223     784    0.656671
# 3        67     267    0.223637
# 4        45     250    0.209398
# ..      ...     ...         ...
# 348     479       1    0.000838
# 349     489       1    0.000838
# 350     229       1    0.000838
# 351     481       1    0.000838
# 352     497       1    0.000838
#
# [353 rows x 3 columns]
# CustomerType: 4 categorías no nulas
#       CustomerType   rows  percentage
# 0        Transient  89613   75.059050
# 1  Transient-Party  25124   21.043638
# 2         Contract   4076    3.414021
# 3            Group    577    0.483290
# ReservationStatus: 3 categorías no nulas
#   ReservationStatus   rows  percentage
# 0         Check-Out  75166   62.958372
# 1          Canceled  43017   36.030656
# 2           No-Show   1207    1.010972
# ReservationStatusDate: 926 categorías no nulas
#     ReservationStatusDate  rows  percentage
# 0              2015-10-21  1461    1.223721
# 1              2015-07-06   805    0.674261
# 2              2016-11-25   790    0.661697
# 3              2015-01-01   763    0.639082
# 4              2016-01-18   625    0.523494
# ..                    ...   ...         ...
# 921            2015-04-21     1    0.000838
# 922            2015-03-13     1    0.000838
# 923            2015-03-29     1    0.000838
# 924            2015-04-27     1    0.000838
# 925            2015-03-10     1    0.000838
#
# [926 rows x 3 columns]

# %% [markdown]
# ### Categorías poco frecuentes
#
# Como apoyo para la inspección se identifican categorías que representan menos del 0,1 % de las reservas. El umbral es exploratorio: no implica que deban agruparse ni eliminarse. En variables como `Country`, una categoría infrecuente puede seguir siendo válida.

# %%
rare_category_threshold = 0.001
rare_category_records = []

for column in categorical_columns:
    counts = bookings_df[column].value_counts(dropna=False)

    for value, count in counts.items():
        proportion = count / len(bookings_df)
        if proportion < rare_category_threshold:
            rare_category_records.append(
                {
                    "column": column,
                    "value": value,
                    "rows": count,
                    "percentage": proportion * 100,
                }
            )

rare_categories_summary = pd.DataFrame(rare_category_records)

if rare_categories_summary.empty:
    print("No se encontraron categorías por debajo del umbral elegido.")
else:
    display(
        rare_categories_summary
        .sort_values(["column", "rows", "value"], na_position="first")
        .reset_index(drop=True)
    )
# Out:
#                      column       value  rows  percentage
# 0                     Agent         114     1    0.000838
# 1                     Agent         117     1    0.000838
# 2                     Agent         144     1    0.000838
# 3                     Agent         158     1    0.000838
# 4                     Agent         165     1    0.000838
# ...                     ...         ...   ...         ...
# 1122  ReservationStatusDate  2017-07-14   119    0.099673
# 1123  ReservationStatusDate  2017-07-30   119    0.099673
# 1124  ReservationStatusDate  2017-08-20   119    0.099673
# 1125       ReservedRoomType           L     6    0.005026
# 1126       ReservedRoomType           P    12    0.010051
#
# [1127 rows x 4 columns]

# %% [markdown]
# ### Posibles categorías duplicadas por formato
#
# Aunque ya se eliminaron espacios exteriores, se comprueba si una misma etiqueta aparece escrita con diferencias de mayúsculas o minúsculas. Este diagnóstico evita generar columnas separadas para una misma categoría durante el preprocesamiento.

# %%
format_collision_records = []

for column in categorical_columns:
    non_null_values = bookings_df[column].dropna().astype(str)
    normalized_groups = (
        pd.DataFrame(
            {
                "original": non_null_values,
                "normalized": non_null_values.str.strip().str.casefold(),
            }
        )
        .groupby("normalized")["original"]
        .agg(lambda values: sorted(set(values)))
    )

    for normalized_value, variants in normalized_groups.items():
        if len(variants) > 1:
            format_collision_records.append(
                {
                    "column": column,
                    "normalized_value": normalized_value,
                    "observed_variants": variants,
                }
            )

format_collisions_summary = pd.DataFrame(format_collision_records)

if format_collisions_summary.empty:
    print("No se encontraron categorías duplicadas por diferencias de formato.")
else:
    display(format_collisions_summary)
# Out:
# No se encontraron categorías duplicadas por diferencias de formato.

# %% [markdown]
# ## Próximos pasos: rangos y valores atípicos
#
# El siguiente bloque analizará las variables numéricas según su significado. No se aplicará una única regla automática a todas las columnas: los identificadores, conteos, importes, proporciones y variables temporales requieren criterios diferentes. Primero se revisarán mínimos, máximos, percentiles y distribuciones; después se distinguirán valores extremos válidos de posibles errores de calidad.

# %% [markdown]
# ## Análisis de rangos y valores atípicos
#
# Las variables se separan según su significado. Los indicadores binarios, las variables de calendario y los identificadores no deben analizarse como medidas continuas. El diagnóstico se concentra en duraciones, cantidades e importes; ningún criterio implica eliminar observaciones automáticamente.

# %%
binary_columns = ["IsCanceled", "IsRepeatedGuest"]
calendar_columns = [
    "ArrivalDateYear", "ArrivalDateMonth",
    "ArrivalDateWeekNumber", "ArrivalDateDayOfMonth",
]
identifier_columns = ["Agent", "Company"]
numeric_analysis_columns = [
    "LeadTime", "StaysInWeekendNights", "StaysInWeekNights",
    "Adults", "Children", "Babies",
    "PreviousCancellations", "PreviousBookingsNotCanceled",
    "BookingChanges", "DaysInWaitingList", "ADR",
    "RequiredCarParkingSpaces", "TotalOfSpecialRequests",
]

missing_numeric_columns = sorted(
    set(numeric_analysis_columns) - set(bookings_df.columns)
)
if missing_numeric_columns:
    raise ValueError(f"Faltan columnas esperadas: {missing_numeric_columns}")

# %% [markdown]
# ### Resumen robusto
#
# Se comparan los extremos con varios percentiles para distinguir valores frecuentes de observaciones aisladas. Los ceros y negativos se contabilizan porque su validez depende del significado de cada variable.

# %%
numeric_data = bookings_df[numeric_analysis_columns]
percentiles = numeric_data.quantile(
    [0.00, 0.01, 0.05, 0.25, 0.50, 0.75, 0.95, 0.99, 1.00]
).T
percentiles.columns = [
    "min", "p01", "p05", "p25", "median",
    "p75", "p95", "p99", "max",
]
numeric_ranges_summary = percentiles.assign(
    null_rows=numeric_data.isna().sum(),
    zero_rows=numeric_data.eq(0).sum(),
    negative_rows=numeric_data.lt(0).sum(),
)
numeric_ranges_summary["zero_percentage"] = (
    numeric_ranges_summary["zero_rows"] / len(bookings_df) * 100
)
numeric_ranges_summary["negative_percentage"] = (
    numeric_ranges_summary["negative_rows"] / len(bookings_df) * 100
)
display(numeric_ranges_summary.round(3))
# Out:
#                               min  p01   p05    p25  median    p75    p95  \
# LeadTime                     0.00  0.0   0.0  18.00  69.000  160.0  320.0
# StaysInWeekendNights         0.00  0.0   0.0   0.00   1.000    2.0    2.0
# StaysInWeekNights            0.00  0.0   0.0   1.00   2.000    3.0    5.0
# Adults                       0.00  1.0   1.0   2.00   2.000    2.0    3.0
# Children                     0.00  0.0   0.0   0.00   0.000    0.0    1.0
# Babies                       0.00  0.0   0.0   0.00   0.000    0.0    0.0
# PreviousCancellations        0.00  0.0   0.0   0.00   0.000    0.0    1.0
# PreviousBookingsNotCanceled  0.00  0.0   0.0   0.00   0.000    0.0    0.0
# BookingChanges               0.00  0.0   0.0   0.00   0.000    0.0    1.0
# DaysInWaitingList            0.00  0.0   0.0   0.00   0.000    0.0    0.0
# ADR                         -6.38  0.0  38.4  69.29  94.575  126.0  193.5
# RequiredCarParkingSpaces     0.00  0.0   0.0   0.00   0.000    0.0    1.0
# TotalOfSpecialRequests       0.00  0.0   0.0   0.00   0.000    1.0    2.0
#
#                                p99     max  null_rows  zero_rows  \
# LeadTime                     444.0   737.0          0       6345
# StaysInWeekendNights           4.0    19.0          0      51998
# StaysInWeekNights             10.0    50.0          0       7645
# Adults                         3.0    55.0          0        403
# Children                       2.0    10.0          4     110796
# Babies                         0.0    10.0          0     118473
# PreviousCancellations          1.0    26.0          0     112906
# PreviousBookingsNotCanceled    3.0    72.0          0     115770
# BookingChanges                 3.0    21.0          0     101314
# DaysInWaitingList             75.0   391.0          0     115692
# ADR                          252.0  5400.0          0       1959
# RequiredCarParkingSpaces       1.0     8.0          0     111974
# TotalOfSpecialRequests         3.0     5.0          0      70318
#
#                              negative_rows  zero_percentage  \
# LeadTime                                 0            5.315
# StaysInWeekendNights                     0           43.553
# StaysInWeekNights                        0            6.403
# Adults                                   0            0.338
# Children                                 0           92.802
# Babies                                   0           99.232
# PreviousCancellations                    0           94.569
# PreviousBookingsNotCanceled              0           96.968
# BookingChanges                           0           84.860
# DaysInWaitingList                        0           96.903
# ADR                                      1            1.641
# RequiredCarParkingSpaces                 0           93.788
# TotalOfSpecialRequests                   0           58.898
#
#                              negative_percentage
# LeadTime                                   0.000
# StaysInWeekendNights                       0.000
# StaysInWeekNights                          0.000
# Adults                                     0.000
# Children                                   0.000
# Babies                                     0.000
# PreviousCancellations                      0.000
# PreviousBookingsNotCanceled                0.000
# BookingChanges                             0.000
# DaysInWaitingList                          0.000
# ADR                                        0.001
# RequiredCarParkingSpaces                   0.000
# TotalOfSpecialRequests                     0.000

# %% [markdown]
# ### Intervalo intercuartílico ampliado
#
# Se cuenta cuántas observaciones quedan fuera de 1,5 veces el rango intercuartílico. Es una descripción de la asimetría, no una clasificación automática de errores. En conteos con muchos ceros incluso un valor positivo puede quedar señalado.

# %%
iqr_records = []
for column in numeric_analysis_columns:
    values = bookings_df[column].dropna()
    q1, q3 = values.quantile([0.25, 0.75])
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outside_mask = values.lt(lower_bound) | values.gt(upper_bound)
    iqr_records.append({
        "column": column,
        "lower_bound": lower_bound,
        "upper_bound": upper_bound,
        "outside_rows": outside_mask.sum(),
        "outside_percentage": outside_mask.mean() * 100,
    })

iqr_outliers_summary = pd.DataFrame(iqr_records).set_index("column")
display(iqr_outliers_summary.round(3))
# Out:
#                              lower_bound  upper_bound  outside_rows  \
# column
# LeadTime                        -195.000      373.000          3005
# StaysInWeekendNights              -3.000        5.000           265
# StaysInWeekNights                 -2.000        6.000          3354
# Adults                             2.000        2.000         29710
# Children                           0.000        0.000          8590
# Babies                             0.000        0.000           917
# PreviousCancellations              0.000        0.000          6484
# PreviousBookingsNotCanceled        0.000        0.000          3620
# BookingChanges                     0.000        0.000         18076
# DaysInWaitingList                  0.000        0.000          3698
# ADR                              -15.775      211.065          3793
# RequiredCarParkingSpaces           0.000        0.000          7416
# TotalOfSpecialRequests            -1.500        2.500          2877
#
#                              outside_percentage
# column
# LeadTime                                  2.517
# StaysInWeekendNights                      0.222
# StaysInWeekNights                         2.809
# Adults                                   24.885
# Children                                  7.195
# Babies                                    0.768
# PreviousCancellations                     5.431
# PreviousBookingsNotCanceled               3.032
# BookingChanges                           15.140
# DaysInWaitingList                         3.097
# ADR                                       3.177
# RequiredCarParkingSpaces                  6.212
# TotalOfSpecialRequests                    2.410

# %% [markdown]
# ### Controles de dominio
#
# Se comprueban condiciones difíciles de justificar por la definición de las variables. Por ahora no se imponen límites superiores: un valor grande puede ser válido y debe inspeccionarse en contexto.

# %%
non_negative_columns = [
    "LeadTime", "StaysInWeekendNights", "StaysInWeekNights",
    "Adults", "Children", "Babies",
    "PreviousCancellations", "PreviousBookingsNotCanceled",
    "BookingChanges", "DaysInWaitingList",
    "RequiredCarParkingSpaces", "TotalOfSpecialRequests",
]
domain_records = [
    {"check": f"Negative {column}", "rows": bookings_df[column].lt(0).sum()}
    for column in non_negative_columns
]
domain_records.extend([
    {"check": "Negative ADR", "rows": bookings_df["ADR"].lt(0).sum()},
    {"check": "Invalid IsCanceled",
     "rows": (~bookings_df["IsCanceled"].isin([0, 1])).sum()},
    {"check": "Invalid IsRepeatedGuest",
     "rows": (~bookings_df["IsRepeatedGuest"].isin([0, 1])).sum()},
])
domain_checks_summary = pd.DataFrame(domain_records)
domain_checks_summary["percentage"] = (
    domain_checks_summary["rows"] / len(bookings_df) * 100
)
display(domain_checks_summary)
# Out:
#                                    check  rows  percentage
# 0                      Negative LeadTime     0    0.000000
# 1          Negative StaysInWeekendNights     0    0.000000
# 2             Negative StaysInWeekNights     0    0.000000
# 3                        Negative Adults     0    0.000000
# 4                      Negative Children     0    0.000000
# 5                        Negative Babies     0    0.000000
# 6         Negative PreviousCancellations     0    0.000000
# 7   Negative PreviousBookingsNotCanceled     0    0.000000
# 8                Negative BookingChanges     0    0.000000
# 9             Negative DaysInWaitingList     0    0.000000
# 10     Negative RequiredCarParkingSpaces     0    0.000000
# 11       Negative TotalOfSpecialRequests     0    0.000000
# 12                          Negative ADR     1    0.000838
# 13                    Invalid IsCanceled     0    0.000000
# 14               Invalid IsRepeatedGuest     0    0.000000

# %% [markdown]
# ### Distribuciones numéricas
#
# Los histogramas se limitan visualmente al percentil 99 para evitar que unos pocos extremos compriman la masa principal. Esos extremos no se eliminan y siguen registrados en el resumen anterior.

# %%
figure, axes = plt.subplots(5, 3, figsize=(18, 22))
axes = axes.flatten()

for axis, column in zip(axes, numeric_analysis_columns):
    upper_visual_limit = bookings_df[column].quantile(0.99)
    visible_values = bookings_df.loc[
        bookings_df[column].le(upper_visual_limit), column
    ].dropna()
    sns.histplot(visible_values, bins=30, ax=axis)
    axis.set_title(f"{column} (hasta p99 = {upper_visual_limit:.2f})")

for axis in axes[len(numeric_analysis_columns):]:
    axis.set_visible(False)

figure.suptitle("Distribuciones numéricas hasta el percentil 99", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Inspección de casos extremos
#
# Se muestran los mayores valores de las variables con rangos más amplios y cualquier `ADR` negativo para estudiar reservas concretas sin alterar los datos.

# %%
extreme_inspection_columns = [
    "ADR", "LeadTime", "StaysInWeekendNights",
    "StaysInWeekNights", "Adults", "Children", "Babies",
    "DaysInWaitingList",
]
context_columns = [
    "HotelType", "IsCanceled", "ReservationStatus",
    "ArrivalDateYear", "ArrivalDateMonth",
]

for column in extreme_inspection_columns:
    print(f"Valores más altos de {column}")
    display(bookings_df.nlargest(10, column)[[*context_columns, column]])

negative_adr_rows = bookings_df.loc[
    bookings_df["ADR"].lt(0),
    [*context_columns, "ADR", "Adults", "Children", "Babies"],
]
if not negative_adr_rows.empty:
    print("Reservas con ADR negativo")
    display(negative_adr_rows)
# Out:
# Valores más altos de ADR
#            HotelType  IsCanceled ReservationStatus  ArrivalDateYear  \
# 48515     City Hotel           1          Canceled             2016
# 111403    City Hotel           0         Check-Out             2017
# 15083   Resort Hotel           0         Check-Out             2015
# 103912    City Hotel           0         Check-Out             2016
# 13142   Resort Hotel           1          Canceled             2017
# 13391   Resort Hotel           1          Canceled             2017
# 39155   Resort Hotel           0         Check-Out             2017
# 39568   Resort Hotel           0         Check-Out             2017
# 39118   Resort Hotel           0         Check-Out             2017
# 13323   Resort Hotel           1          Canceled             2017
#
#        ArrivalDateMonth      ADR
# 48515             March  5400.00
# 111403              May   510.00
# 15083              July   508.00
# 103912         December   451.50
# 13142            August   450.00
# 13391            August   437.00
# 39155            August   426.25
# 39568            August   402.00
# 39118              July   397.38
# 13323            August   392.00
# Valores más altos de LeadTime
#           HotelType  IsCanceled ReservationStatus  ArrivalDateYear  \
# 1      Resort Hotel           0         Check-Out             2015
# 4182   Resort Hotel           0         Check-Out             2016
# 65231    City Hotel           1          Canceled             2017
# 65235    City Hotel           1          Canceled             2017
# 65237    City Hotel           1          Canceled             2017
# 65238    City Hotel           1          Canceled             2017
# 65239    City Hotel           1          Canceled             2017
# 65240    City Hotel           1          Canceled             2017
# 65241    City Hotel           1          Canceled             2017
# 65242    City Hotel           1          Canceled             2017
#
#       ArrivalDateMonth  LeadTime
# 1                 July       737
# 4182          February       709
# 65231            March       629
# 65235            March       629
# 65237            March       629
# 65238            March       629
# 65239            March       629
# 65240            March       629
# 65241            March       629
# 65242            March       629
# Valores más altos de StaysInWeekendNights
#            HotelType  IsCanceled ReservationStatus  ArrivalDateYear  \
# 14038   Resort Hotel           0         Check-Out             2016
# 14037   Resort Hotel           0         Check-Out             2015
# 9839    Resort Hotel           1          Canceled             2017
# 33924   Resort Hotel           0         Check-Out             2017
# 101794    City Hotel           0         Check-Out             2016
# 54704     City Hotel           0         Check-Out             2016
# 88017     City Hotel           0         Check-Out             2016
# 1655    Resort Hotel           0         Check-Out             2015
# 32589   Resort Hotel           0         Check-Out             2017
# 106561    City Hotel           0         Check-Out             2017
#
#        ArrivalDateMonth  StaysInWeekendNights
# 14038              July                    19
# 14037            August                    18
# 9839            January                    16
# 33924           January                    16
# 101794        September                    16
# 54704              July                    14
# 88017             March                    14
# 1655          September                    13
# 32589          February                    13
# 106561          January                    13
# Valores más altos de StaysInWeekNights
#            HotelType  IsCanceled ReservationStatus  ArrivalDateYear  \
# 14038   Resort Hotel           0         Check-Out             2016
# 14037   Resort Hotel           0         Check-Out             2015
# 101794    City Hotel           0         Check-Out             2016
# 9839    Resort Hotel           1          Canceled             2017
# 33924   Resort Hotel           0         Check-Out             2017
# 88017     City Hotel           0         Check-Out             2016
# 54704     City Hotel           0         Check-Out             2016
# 1655    Resort Hotel           0         Check-Out             2015
# 32589   Resort Hotel           0         Check-Out             2017
# 3820    Resort Hotel           1          Canceled             2016
#
#        ArrivalDateMonth  StaysInWeekNights
# 14038              July                 50
# 14037            August                 42
# 101794        September                 41
# 9839            January                 40
# 33924           January                 40
# 88017             March                 35
# 54704              July                 34
# 1655          September                 33
# 32589          February                 32
# 3820            January                 30
# Valores más altos de Adults
#          HotelType  IsCanceled ReservationStatus  ArrivalDateYear  \
# 2173  Resort Hotel           1          Canceled             2015
# 1643  Resort Hotel           1          Canceled             2015
# 1539  Resort Hotel           1          Canceled             2015
# 1917  Resort Hotel           1          Canceled             2015
# 1962  Resort Hotel           1          Canceled             2015
# 1587  Resort Hotel           1          Canceled             2015
# 1752  Resort Hotel           1          Canceled             2015
# 1884  Resort Hotel           1          Canceled             2015
# 2003  Resort Hotel           1          Canceled             2015
# 2164  Resort Hotel           1          Canceled             2015
#
#      ArrivalDateMonth  Adults
# 2173          October      55
# 1643        September      50
# 1539        September      40
# 1917        September      27
# 1962        September      27
# 1587        September      26
# 1752        September      26
# 1884        September      26
# 2003        September      26
# 2164          October      26
# Valores más altos de Children
#           HotelType  IsCanceled ReservationStatus  ArrivalDateYear  \
# 328    Resort Hotel           1           No-Show             2015
# 6748   Resort Hotel           1          Canceled             2016
# 7666   Resort Hotel           1          Canceled             2016
# 16360  Resort Hotel           0         Check-Out             2015
# 18745  Resort Hotel           0         Check-Out             2015
# 18746  Resort Hotel           0         Check-Out             2016
# 19718  Resort Hotel           0         Check-Out             2016
# 21005  Resort Hotel           0         Check-Out             2016
# 22636  Resort Hotel           0         Check-Out             2016
# 23407  Resort Hotel           0         Check-Out             2016
#
#       ArrivalDateMonth  Children
# 328               July      10.0
# 6748              June       3.0
# 7666            August       3.0
# 16360           August       3.0
# 18745         November       3.0
# 18746         November       3.0
# 19718          January       3.0
# 21005         February       3.0
# 22636            March       3.0
# 23407            April       3.0
# Valores más altos de Babies
#           HotelType  IsCanceled ReservationStatus  ArrivalDateYear  \
# 46619    City Hotel           0         Check-Out             2016
# 78656    City Hotel           0         Check-Out             2015
# 264    Resort Hotel           0         Check-Out             2015
# 6719   Resort Hotel           1          Canceled             2016
# 7896   Resort Hotel           1          Canceled             2016
# 14556  Resort Hotel           0         Check-Out             2016
# 16677  Resort Hotel           0         Check-Out             2015
# 29906  Resort Hotel           0         Check-Out             2016
# 33332  Resort Hotel           0         Check-Out             2017
# 37302  Resort Hotel           0         Check-Out             2017
#
#       ArrivalDateMonth  Babies
# 46619          January      10
# 78656          October       9
# 264               July       2
# 6719              June       2
# 7896         September       2
# 14556         December       2
# 16677        September       2
# 29906         November       2
# 33332         February       2
# 37302             June       2
# Valores más altos de DaysInWaitingList
#         HotelType  IsCanceled ReservationStatus  ArrivalDateYear  \
# 58152  City Hotel           1          Canceled             2016
# 58153  City Hotel           1          Canceled             2016
# 58154  City Hotel           1          Canceled             2016
# 58155  City Hotel           1          Canceled             2016
# 58157  City Hotel           1          Canceled             2016
# 58158  City Hotel           1          Canceled             2016
# 58159  City Hotel           1          Canceled             2016
# 58160  City Hotel           1          Canceled             2016
# 58161  City Hotel           1          Canceled             2016
# 58167  City Hotel           1          Canceled             2016
#
#       ArrivalDateMonth  DaysInWaitingList
# 58152          October                391
# 58153          October                391
# 58154          October                391
# 58155          October                391
# 58157          October                391
# 58158          October                391
# 58159          October                391
# 58160          October                391
# 58161          October                391
# 58167          October                391
# Reservas con ADR negativo
#           HotelType  IsCanceled ReservationStatus  ArrivalDateYear  \
# 14969  Resort Hotel           0         Check-Out             2017
#
#       ArrivalDateMonth   ADR  Adults  Children  Babies
# 14969            March -6.38       2       0.0       0

# %% [markdown]
# ### Análisis contextual de cantidades extremas de huéspedes
#
# Los máximos de `Adults`, `Children` y `Babies` están separados de los valores habituales. Se inspeccionan usando umbrales basados en esos saltos observados, no como límites universales de validez. El objetivo es evaluar si corresponden a reservas grupales coherentes, patrones repetidos o posibles errores de registro.

# %%
guest_extreme_masks = {
    "Adults > 10": bookings_df["Adults"].gt(10),
    "Children > 3": bookings_df["Children"].gt(3),
    "Babies > 2": bookings_df["Babies"].gt(2),
}

guest_extremes_summary = pd.DataFrame(
    {
        "case": guest_extreme_masks.keys(),
        "rows": [mask.sum() for mask in guest_extreme_masks.values()],
    }
)
guest_extremes_summary["percentage"] = (
    guest_extremes_summary["rows"] / len(bookings_df) * 100
)
display(guest_extremes_summary)
# Out:
#            case  rows  percentage
# 0   Adults > 10    12    0.010051
# 1  Children > 3     1    0.000838
# 2    Babies > 2     2    0.001675

# %%
guest_context_columns = [
    "HotelType", "ArrivalDateYear", "ArrivalDateMonth",
    "Adults", "Children", "Babies",
    "StaysInWeekendNights", "StaysInWeekNights",
    "ReservedRoomType", "AssignedRoomType",
    "MarketSegment", "DistributionChannel",
    "CustomerType", "Agent", "Company",
    "ADR", "IsCanceled", "ReservationStatus",
]

for case, mask in guest_extreme_masks.items():
    print(case)
    display(
        bookings_df.loc[mask, guest_context_columns]
        .sort_values(["Adults", "Children", "Babies"], ascending=False)
    )
# Out:
# Adults > 10
#          HotelType  ArrivalDateYear ArrivalDateMonth  Adults  Children  \
# 2173  Resort Hotel             2015          October      55       0.0
# 1643  Resort Hotel             2015        September      50       0.0
# 1539  Resort Hotel             2015        September      40       0.0
# 1917  Resort Hotel             2015        September      27       0.0
# 1962  Resort Hotel             2015        September      27       0.0
# 1587  Resort Hotel             2015        September      26       0.0
# 1752  Resort Hotel             2015        September      26       0.0
# 1884  Resort Hotel             2015        September      26       0.0
# 2003  Resort Hotel             2015        September      26       0.0
# 2164  Resort Hotel             2015          October      26       0.0
# 2228  Resort Hotel             2015          October      20       0.0
# 2418  Resort Hotel             2015          October      20       0.0
#
#       Babies  StaysInWeekendNights  StaysInWeekNights ReservedRoomType  \
# 2173       0                     2                  0                A
# 1643       0                     1                  2                A
# 1539       0                     0                  3                A
# 1917       0                     1                  3                A
# 1962       0                     1                  3                A
# 1587       0                     2                  5                A
# 1752       0                     2                  5                A
# 1884       0                     2                  5                A
# 2003       0                     2                  5                A
# 2164       0                     2                  5                A
# 2228       0                     2                  5                D
# 2418       0                     2                  5                D
#
#      AssignedRoomType  MarketSegment DistributionChannel CustomerType Agent  \
# 2173                A         Direct              Direct        Group   NaN
# 1643                A         Direct              Direct        Group   NaN
# 1539                A         Direct              Direct        Group   NaN
# 1917                A         Direct              Direct        Group   NaN
# 1962                A         Direct              Direct        Group   NaN
# 1587                A  Offline TA/TO               TA/TO        Group    96
# 1752                A  Offline TA/TO               TA/TO        Group    96
# 1884                A  Offline TA/TO               TA/TO        Group    96
# 2003                A  Offline TA/TO               TA/TO        Group    96
# 2164                A  Offline TA/TO               TA/TO        Group    96
# 2228                D         Direct              Direct        Group   NaN
# 2418                D         Direct              Direct        Group   NaN
#
#      Company  ADR  IsCanceled ReservationStatus
# 2173     NaN  0.0           1          Canceled
# 1643     NaN  0.0           1          Canceled
# 1539     NaN  0.0           1          Canceled
# 1917     NaN  0.0           1          Canceled
# 1962     NaN  0.0           1          Canceled
# 1587     NaN  0.0           1          Canceled
# 1752     NaN  0.0           1          Canceled
# 1884     NaN  0.0           1          Canceled
# 2003     NaN  0.0           1          Canceled
# 2164     NaN  0.0           1          Canceled
# 2228     NaN  0.0           1          Canceled
# 2418     NaN  0.0           1          Canceled
# Children > 3
#         HotelType  ArrivalDateYear ArrivalDateMonth  Adults  Children  Babies  \
# 328  Resort Hotel             2015             July       2      10.0       0
#
#      StaysInWeekendNights  StaysInWeekNights ReservedRoomType  \
# 328                     4                 10                D
#
#     AssignedRoomType  MarketSegment DistributionChannel CustomerType Agent  \
# 328                D  Offline TA/TO               TA/TO     Contract     8
#
#     Company     ADR  IsCanceled ReservationStatus
# 328     NaN  133.16           1           No-Show
# Babies > 2
#         HotelType  ArrivalDateYear ArrivalDateMonth  Adults  Children  Babies  \
# 46619  City Hotel             2016          January       2       0.0      10
# 78656  City Hotel             2015          October       1       0.0       9
#
#        StaysInWeekendNights  StaysInWeekNights ReservedRoomType  \
# 46619                     0                  2                D
# 78656                     2                  1                A
#
#       AssignedRoomType MarketSegment DistributionChannel     CustomerType  \
# 46619                D     Online TA               TA/TO        Transient
# 78656                B     Corporate           Corporate  Transient-Party
#
#       Agent Company    ADR  IsCanceled ReservationStatus
# 46619     9     NaN  84.45           0         Check-Out
# 78656    95     NaN  95.00           0         Check-Out

# %% [markdown]
# ### Patrones compartidos entre los casos extremos
#
# Las reservas grupales pueden aparecer como varias filas relacionadas. Para reconocer esos patrones se resumen las variables de contexto y se buscan combinaciones repetidas sin asumir que sean filas duplicadas.

# %%
all_guest_extremes_mask = np.logical_or.reduce(
    list(guest_extreme_masks.values())
)
guest_extreme_rows = bookings_df.loc[all_guest_extremes_mask].copy()
guest_extreme_rows["TotalGuests"] = guest_extreme_rows[
    ["Adults", "Children", "Babies"]
].sum(axis=1, min_count=3)
guest_extreme_rows["TotalNights"] = guest_extreme_rows[
    ["StaysInWeekendNights", "StaysInWeekNights"]
].sum(axis=1)

pattern_columns = [
    "HotelType", "ArrivalDateYear", "ArrivalDateMonth",
    "MarketSegment", "DistributionChannel", "CustomerType",
    "Adults", "Children", "Babies", "IsCanceled",
]
guest_extreme_patterns = (
    guest_extreme_rows.groupby(pattern_columns, dropna=False)
    .size()
    .rename("rows")
    .reset_index()
    .sort_values("rows", ascending=False)
)

display(guest_extreme_patterns)
display(
    guest_extreme_rows[[
        "Adults", "Children", "Babies",
        "TotalGuests", "TotalNights", "ADR",
    ]].describe()
)
# Out:
#       HotelType  ArrivalDateYear ArrivalDateMonth  MarketSegment  \
# 9  Resort Hotel             2015        September  Offline TA/TO
# 3  Resort Hotel             2015          October         Direct
# 6  Resort Hotel             2015        September         Direct
# 0    City Hotel             2015          October      Corporate
# 1    City Hotel             2016          January      Online TA
# 2  Resort Hotel             2015             July  Offline TA/TO
# 5  Resort Hotel             2015          October  Offline TA/TO
# 4  Resort Hotel             2015          October         Direct
# 7  Resort Hotel             2015        September         Direct
# 8  Resort Hotel             2015        September         Direct
#
#   DistributionChannel     CustomerType  Adults  Children  Babies  IsCanceled  \
# 9               TA/TO            Group      26       0.0       0           1
# 3              Direct            Group      20       0.0       0           1
# 6              Direct            Group      27       0.0       0           1
# 0           Corporate  Transient-Party       1       0.0       9           0
# 1               TA/TO        Transient       2       0.0      10           0
# 2               TA/TO         Contract       2      10.0       0           1
# 5               TA/TO            Group      26       0.0       0           1
# 4              Direct            Group      55       0.0       0           1
# 7              Direct            Group      40       0.0       0           1
# 8              Direct            Group      50       0.0       0           1
#
#    rows
# 9     4
# 3     2
# 6     2
# 0     1
# 1     1
# 2     1
# 5     1
# 4     1
# 7     1
# 8     1
#           Adults   Children     Babies  TotalGuests  TotalNights         ADR
# count  15.000000  15.000000  15.000000    15.000000    15.000000   15.000000
# mean   24.933333   0.666667   1.266667    26.866667     5.600000   20.840667
# std    15.691065   2.581989   3.348063    12.883360     3.112188   44.218118
# min     1.000000   0.000000   0.000000    10.000000     2.000000    0.000000
# 25%    20.000000   0.000000   0.000000    20.000000     3.000000    0.000000
# 50%    26.000000   0.000000   0.000000    26.000000     7.000000    0.000000
# 75%    27.000000   0.000000   0.000000    27.000000     7.000000    0.000000
# max    55.000000  10.000000  10.000000    55.000000    14.000000  133.160000

# %% [markdown]
# Los casos se mantienen sin cambios durante el EDA. A partir de su contexto se documentará si parecen reservas grupales plausibles o valores difíciles de justificar; cualquier tratamiento se decidirá más adelante y se comparará dentro del proceso de modelado.

# %% [markdown]
# ## Conclusiones preliminares de calidad y rangos
#
# ### Valores ausentes y categorías especiales
#
# Después de eliminar espacios exteriores y convertir la etiqueta textual `NULL` en un nulo real, las columnas con valores ausentes son `Company`, `Agent`, `Country` y `Children`. La ausencia de `Agent` y `Company` parece ser principalmente estructural: estas variables identifican a la agencia o empresa asociada con la reserva y no necesariamente aplican a todas las operaciones. Por ello, no corresponde interpretar automáticamente sus nulos como información desconocida ni imputarlos con la categoría más frecuente.
#
# También se encontraron las categorías `Undefined` en `Meal`, `MarketSegment` y `DistributionChannel`. En `Meal`, la documentación del dataset relaciona `Undefined` y `SC` con reservas sin paquete de comidas, aunque ambas etiquetas se conservarán separadas durante el EDA para comprobar su comportamiento antes de considerar una agrupación. Los casos `Undefined` de segmento y canal son muy escasos y quedan registrados para su tratamiento posterior.
#
# ### Reservas sin huéspedes o sin noches
#
# Se identificaron 180 reservas sin huéspedes registrados, 715 con cero noches y 70 que cumplen ambas condiciones. La mayoría figura con estado `Check-Out`, por lo que no pueden explicarse únicamente como reservas canceladas o incompletas. Las estadías de cero noches podrían corresponder a uso diurno o registros administrativos; las reservas sin huéspedes resultan más difíciles de interpretar. Se mantienen durante el EDA y su impacto se evaluará posteriormente mediante análisis de sensibilidad.
#
# ### Rangos y valores atípicos
#
# Las distribuciones de duraciones y conteos son fuertemente asimétricas y contienen muchos ceros. Como consecuencia, el criterio del rango intercuartílico señala numerosos valores que no son necesariamente errores. No se utilizará este criterio como una regla automática de eliminación. Los valores altos de `LeadTime`, noches de estadía y días en lista de espera son inusuales, pero resultan operativamente posibles.
#
# `ADR` presenta dos observaciones particularmente anómalas: un valor negativo de -6,38 y un máximo de 5400. El máximo está ampliamente separado del resto de la distribución: el percentil 99 es 252 y el segundo valor más alto es 510. El dataset no permite determinar si se trata de errores de registro, ajustes comerciales o situaciones excepcionales. Ambos casos se conservan y se considerarán alternativas de tratamiento durante Feature Engineering, especialmente para los modelos sensibles al escalado y a valores extremos.
#
# ### Cantidades extremas de huéspedes
#
# Las 12 reservas con más de 10 adultos pertenecen al `Resort Hotel`, están clasificadas como `Group`, tienen `ADR` igual a cero y fueron canceladas. Varias comparten fecha, duración, agencia y cantidad de adultos, lo que aporta coherencia con la interpretación de reservas grupales o bloques de habitaciones. Estos valores altos de `Adults` se consideran plausibles y se conservarán. Sin embargo, representan solamente el 0,01 % del dataset y no permiten generalizar que todas las reservas grupales grandes tengan el mismo comportamiento.
#
# El único caso con 10 niños podría representar una reserva colectiva, aunque no está clasificado como `Group`. Los dos registros con 9 y 10 bebés son más difíciles de justificar: corresponden a reservas con uno o dos adultos y finalizaron en `Check-Out`. Se mantienen por ahora, pero quedan señalados como posibles errores de registro para evaluar su tratamiento posteriormente.
#
# Estas conclusiones describen la evidencia encontrada y servirán como entrada para Feature Analysis y Feature Engineering. En este notebook no se eliminan observaciones ni se definen todavía reglas de imputación o transformación.

# %% [markdown]
# ## Revisión de duplicados y patrones repetidos
#
# El dataset no contiene un identificador único de reserva. Por ese motivo, dos filas idénticas pueden ser duplicados técnicos, pero también reservas diferentes pertenecientes a un mismo grupo o realizadas bajo las mismas condiciones. El análisis cuantifica las coincidencias sin eliminarlas.

# %% [markdown]
# ### Filas completamente duplicadas
#
# Se consideran todas las columnas disponibles, incluido el resultado final. Se informa tanto la cantidad de filas que participan en grupos repetidos como la cantidad que quedaría al conservar una sola aparición por combinación.

# %%
exact_duplicate_mask = bookings_df.duplicated(keep=False)
exact_redundant_mask = bookings_df.duplicated(keep="first")

exact_duplicates_summary = pd.DataFrame(
    {
        "measure": [
            "Rows participating in exact duplicate groups",
            "Rows removed if one copy per group were retained",
            "Rows remaining after a hypothetical deduplication",
        ],
        "rows": [
            exact_duplicate_mask.sum(),
            exact_redundant_mask.sum(),
            len(bookings_df) - exact_redundant_mask.sum(),
        ],
    }
)
exact_duplicates_summary["percentage_of_dataset"] = (
    exact_duplicates_summary["rows"] / len(bookings_df) * 100
)
display(exact_duplicates_summary)
# Out:
#                                              measure   rows  \
# 0       Rows participating in exact duplicate groups  40165
# 1   Rows removed if one copy per group were retained  31994
# 2  Rows remaining after a hypothetical deduplication  87396
#
#    percentage_of_dataset
# 0              33.641846
# 1              26.797889
# 2              73.202111

# %%
exact_duplicate_groups = (
    bookings_df.loc[exact_duplicate_mask]
    .groupby(bookings_df.columns.tolist(), dropna=False)
    .size()
    .rename("repetitions")
    .reset_index()
    .sort_values("repetitions", ascending=False)
)

exact_group_size_summary = (
    exact_duplicate_groups["repetitions"]
    .value_counts()
    .sort_index()
    .rename_axis("repetitions_per_combination")
    .reset_index(name="combinations")
)
display(exact_group_size_summary)
display(exact_duplicate_groups.head(10))
# Out:
#     repetitions_per_combination  combinations
# 0                             2          5034
# 1                             3           969
# 2                             4           497
# 3                             5           275
# 4                             6           171
# ..                          ...           ...
# 67                          100             1
# 68                          101             1
# 69                          109             1
# 70                          150             1
# 71                          180             1
#
# [72 rows x 2 columns]
#        HotelType  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 5407  City Hotel           1       277             2016         November
# 4183  City Hotel           1        68             2016         February
# 5077  City Hotel           1       188             2016             June
# 4881  City Hotel           1       158             2016              May
# 3852  City Hotel           1        34             2015         December
# 4874  City Hotel           1       156             2017            April
# 3794  City Hotel           1        28             2017            March
# 3908  City Hotel           1        38             2017          January
# 4207  City Hotel           1        71             2016             June
# 5527  City Hotel           1       305             2016         November
#
#       ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 5407                     46                      7                     1
# 4183                      8                     17                     0
# 5077                     25                     15                     0
# 4881                     22                     24                     0
# 3852                     50                      8                     0
# 4874                     17                     26                     0
# 3794                      9                      2                     0
# 3908                      2                     14                     0
# 4207                     25                     14                     0
# 5527                     45                      4                     1
#
#       StaysInWeekNights  Adults  Children  Babies Meal Country  MarketSegment  \
# 5407                  2       2       0.0       0   BB     PRT         Groups
# 4183                  2       2       0.0       0   BB     PRT         Groups
# 5077                  2       1       0.0       0   BB     PRT  Offline TA/TO
# 4881                  2       1       0.0       0   BB     PRT         Groups
# 3852                  2       1       0.0       0   BB     PRT  Offline TA/TO
# 4874                  3       2       0.0       0   BB     PRT         Groups
# 3794                  3       2       0.0       0   BB     PRT         Groups
# 3908                  1       1       0.0       0   BB     PRT      Corporate
# 4207                  3       1       0.0       0   BB     PRT  Offline TA/TO
# 5527                  2       2       0.0       0   BB     PRT  Offline TA/TO
#
#      DistributionChannel  IsRepeatedGuest  PreviousCancellations  \
# 5407               TA/TO                0                      0
# 4183               TA/TO                0                      1
# 5077               TA/TO                0                      0
# 4881               TA/TO                0                      0
# 3852               TA/TO                0                      1
# 4874               TA/TO                0                      0
# 3794               TA/TO                0                      0
# 3908           Corporate                0                      0
# 4207               TA/TO                0                      0
# 5527               TA/TO                0                      0
#
#       PreviousBookingsNotCanceled ReservedRoomType AssignedRoomType  \
# 5407                            0                A                A
# 4183                            0                A                A
# 5077                            0                A                A
# 4881                            0                A                A
# 3852                            0                A                A
# 4874                            0                A                A
# 3794                            0                A                A
# 3908                            0                A                A
# 4207                            0                A                A
# 5527                            0                A                A
#
#       BookingChanges DepositType Agent Company  DaysInWaitingList  \
# 5407               0  Non Refund   NaN     NaN                  0
# 4183               0  Non Refund    37     NaN                  0
# 5077               0  Non Refund   119     NaN                 39
# 4881               0  Non Refund    37     NaN                 31
# 3852               0  Non Refund    19     NaN                  0
# 4874               0  Non Refund    37     NaN                  0
# 3794               0  Non Refund   NaN     NaN                  0
# 3908               0  Non Refund   NaN      67                  0
# 4207               0  Non Refund   236     NaN                  0
# 5527               0  Non Refund    21     NaN                  0
#
#      CustomerType    ADR  RequiredCarParkingSpaces  TotalOfSpecialRequests  \
# 5407    Transient  100.0                         0                       0
# 4183    Transient   75.0                         0                       0
# 5077    Transient  130.0                         0                       0
# 4881    Transient  130.0                         0                       0
# 3852    Transient   90.0                         0                       0
# 4874    Transient  100.0                         0                       0
# 3794    Transient   95.0                         0                       0
# 3908    Transient   75.0                         0                       0
# 4207    Transient  120.0                         0                       0
# 5527    Transient   89.0                         0                       0
#
#      ReservationStatus ReservationStatusDate  repetitions
# 5407          Canceled            2016-04-04          180
# 4183          Canceled            2016-01-06          150
# 5077          Canceled            2016-01-18          109
# 4881          Canceled            2016-01-18          101
# 3852          Canceled            2015-11-17          100
# 4874          Canceled            2016-11-21           99
# 3794          Canceled            2017-02-02           99
# 3908          Canceled            2016-12-07           99
# 4207          Canceled            2016-04-27           89
# 5527          Canceled            2016-02-01           85

# %% [markdown]
# ### Predictores coincidentes y resultados diferentes
#
# Para aproximar el problema desde el momento de predicción se excluyen `IsCanceled`, `ReservationStatus` y `ReservationStatusDate`. Se buscan reservas que comparten todos los predictores registrados y se comprueba si dentro de una misma combinación aparecen resultados de cancelación diferentes. Esto permite observar que una coincidencia de variables no identifica necesariamente una única reserva.

# %%
outcome_columns = ["IsCanceled", "ReservationStatus", "ReservationStatusDate"]
predictor_columns = [
    column for column in bookings_df.columns if column not in outcome_columns
]
predictor_duplicate_mask = bookings_df.duplicated(
    subset=predictor_columns, keep=False
)
predictor_redundant_mask = bookings_df.duplicated(
    subset=predictor_columns, keep="first"
)

predictor_groups = (
    bookings_df.loc[predictor_duplicate_mask]
    .groupby(predictor_columns, dropna=False)
    .agg(
        rows=("IsCanceled", "size"),
        cancellation_values=("IsCanceled", "nunique"),
        cancellation_rate=("IsCanceled", "mean"),
        status_values=("ReservationStatus", "nunique"),
        status_date_values=("ReservationStatusDate", "nunique"),
    )
    .reset_index()
)
conflicting_predictor_groups = predictor_groups.loc[
    predictor_groups["cancellation_values"].gt(1)
]

predictor_duplicates_summary = pd.DataFrame(
    {
        "measure": [
            "Rows participating in repeated predictor combinations",
            "Repeated rows beyond the first predictor combination",
            "Repeated predictor combinations",
            "Predictor combinations with different targets",
            "Rows in predictor combinations with different targets",
        ],
        "rows_or_groups": [
            predictor_duplicate_mask.sum(),
            predictor_redundant_mask.sum(),
            len(predictor_groups),
            len(conflicting_predictor_groups),
            conflicting_predictor_groups["rows"].sum(),
        ],
    }
)
display(predictor_duplicates_summary)
# Out:
#                                              measure  rows_or_groups
# 0  Rows participating in repeated predictor combi...           40754
# 1  Repeated rows beyond the first predictor combi...           32517
# 2                    Repeated predictor combinations            8237
# 3      Predictor combinations with different targets             265
# 4  Rows in predictor combinations with different ...            1812

# %%
conflicting_group_examples = (
    conflicting_predictor_groups
    .sort_values(["rows", "status_date_values"], ascending=False)
    .head(10)
)
display(conflicting_group_examples)
# Out:
#          HotelType  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 3757    City Hotel       134             2017         February
# 4199    City Hotel       164             2015          October
# 2066    City Hotel        55             2016            April
# 4201    City Hotel       164             2015          October
# 6681  Resort Hotel        40             2017          January
# 5484    City Hotel       316             2016              May
# 2129    City Hotel        57             2016             June
# 4242    City Hotel       168             2015        September
# 700     City Hotel        12             2015             July
# 3534    City Hotel       122             2016            April
#
#       ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 3757                      8                     25                     0
# 4199                     40                      2                     0
# 2066                     15                      6                     0
# 4201                     40                      2                     0
# 6681                      3                     16                     1
# 5484                     22                     26                     0
# 2129                     24                     10                     1
# 4242                     37                     11                     0
# 700                      29                     18                     2
# 3534                     16                     15                     0
#
#       StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 3757                  1       1       0.0       0         BB     PRT
# 4199                  2       1       0.0       0         BB     PRT
# 2066                  1       2       0.0       0         HB     PRT
# 4201                  2       1       0.0       0         BB     PRT
# 6681                  2       1       0.0       0  Undefined     PRT
# 5484                  3       2       0.0       0         BB     PRT
# 2129                  2       2       0.0       0         BB     PRT
# 4242                  2       2       0.0       0         BB     PRT
# 700                   2       2       0.0       0         BB     PRT
# 3534                  2       2       0.0       0         BB     PRT
#
#       MarketSegment DistributionChannel  IsRepeatedGuest  \
# 3757         Groups               TA/TO                0
# 4199  Offline TA/TO               TA/TO                0
# 2066  Offline TA/TO               TA/TO                0
# 4201  Offline TA/TO               TA/TO                0
# 6681         Groups              Direct                0
# 5484         Groups               TA/TO                0
# 2129  Offline TA/TO               TA/TO                0
# 4242         Groups               TA/TO                0
# 700          Groups               TA/TO                0
# 3534  Offline TA/TO               TA/TO                0
#
#       PreviousCancellations  PreviousBookingsNotCanceled ReservedRoomType  \
# 3757                      0                            0                A
# 4199                      0                            0                A
# 2066                      0                            0                A
# 4201                      0                            0                A
# 6681                      0                            0                A
# 5484                      0                            0                A
# 2129                      0                            0                A
# 4242                      0                            0                A
# 700                       0                            0                A
# 3534                      0                            0                A
#
#      AssignedRoomType  BookingChanges DepositType Agent Company  \
# 3757                A               0  No Deposit    30     NaN
# 4199                A               0  No Deposit    19     NaN
# 2066                A               0  No Deposit    56     NaN
# 4201                D               0  No Deposit    19     NaN
# 6681                A               0  No Deposit   NaN     NaN
# 5484                A               0  No Deposit    30     NaN
# 2129                A               0  No Deposit     6     NaN
# 4242                A               0  No Deposit     1     NaN
# 700                 A               0  No Deposit     1     NaN
# 3534                A               0  No Deposit   151     NaN
#
#       DaysInWaitingList     CustomerType     ADR  RequiredCarParkingSpaces  \
# 3757                  0  Transient-Party   75.00                         0
# 4199                  0  Transient-Party  100.00                         0
# 2066                  0  Transient-Party  104.00                         0
# 4201                  0  Transient-Party  100.00                         0
# 6681                  0  Transient-Party   55.00                         0
# 5484                  0  Transient-Party  110.00                         0
# 2129                  0  Transient-Party   90.67                         0
# 4242                  0  Transient-Party   60.00                         0
# 700                   0  Transient-Party   62.00                         0
# 3534                 56  Transient-Party   85.00                         0
#
#       TotalOfSpecialRequests  rows  cancellation_values  cancellation_rate  \
# 3757                       0   107                    2           0.476636
# 4199                       0    52                    2           0.115385
# 2066                       0    43                    2           0.046512
# 4201                       0    38                    2           0.078947
# 6681                       0    37                    2           0.216216
# 5484                       0    34                    2           0.029412
# 2129                       1    28                    2           0.071429
# 4242                       0    26                    2           0.423077
# 700                        0    26                    2           0.615385
# 3534                       0    24                    2           0.333333
#
#       status_values  status_date_values
# 3757              3                   3
# 4199              2                   4
# 2066              2                   2
# 4201              2                   2
# 6681              2                   6
# 5484              2                   2
# 2129              2                   2
# 4242              2                   3
# 700               2                   2
# 3534              2                   2

# %% [markdown]
# ### Patrones comerciales repetidos
#
# Finalmente se agrupan variables que describen el contexto de llegada, huéspedes y condiciones generales de la reserva. Estas coincidencias son patrones operativos, no duplicados: es esperable que muchas personas reserven bajo configuraciones similares.

# %%
business_pattern_columns = [
    "HotelType", "ArrivalDateYear", "ArrivalDateMonth",
    "ArrivalDateWeekNumber", "ArrivalDateDayOfMonth",
    "Adults", "Children", "Babies",
    "StaysInWeekendNights", "StaysInWeekNights",
    "Meal", "MarketSegment", "DistributionChannel",
    "ReservedRoomType", "DepositType", "CustomerType",
]
business_patterns = (
    bookings_df.groupby(business_pattern_columns, dropna=False)
    .agg(
        rows=("IsCanceled", "size"),
        cancellation_rate=("IsCanceled", "mean"),
        distinct_agents=("Agent", "nunique"),
        distinct_companies=("Company", "nunique"),
    )
    .reset_index()
    .sort_values("rows", ascending=False)
)
display(business_patterns.head(20))
# Out:
#           HotelType  ArrivalDateYear ArrivalDateMonth  ArrivalDateWeekNumber  \
# 16300    City Hotel             2016         November                     46
# 942      City Hotel             2015         December                     50
# 329      City Hotel             2015           August                     33
# 9250     City Hotel             2016         February                      8
# 3897     City Hotel             2015        September                     38
# 2809     City Hotel             2015          October                     42
# 21367    City Hotel             2017            April                     17
# 31039    City Hotel             2017              May                     20
# 9647     City Hotel             2016         February                     10
# 24288    City Hotel             2017         February                      8
# 12923    City Hotel             2016             June                     26
# 12560    City Hotel             2016             June                     25
# 2326     City Hotel             2015          October                     40
# 15752    City Hotel             2016              May                     22
# 28970    City Hotel             2017            March                      9
# 24955    City Hotel             2017          January                      2
# 15816    City Hotel             2016              May                     22
# 52217  Resort Hotel             2017          January                      3
# 12518    City Hotel             2016             June                     25
# 31811    City Hotel             2017              May                     22
#
#        ArrivalDateDayOfMonth  Adults  Children  Babies  StaysInWeekendNights  \
# 16300                      7       2       0.0       0                     1
# 942                        8       1       0.0       0                     0
# 329                       14       2       0.0       0                     0
# 9250                      17       2       0.0       0                     0
# 3897                      18       2       0.0       0                     0
# 2809                      16       2       0.0       0                     0
# 21367                     26       2       0.0       0                     0
# 31039                     15       1       0.0       0                     1
# 9647                      28       1       0.0       0                     2
# 24288                     25       1       0.0       0                     0
# 12923                     24       1       0.0       0                     0
# 12560                     15       1       0.0       0                     0
# 2326                       2       1       0.0       0                     0
# 15752                     24       1       0.0       0                     0
# 28970                      2       2       0.0       0                     0
# 24955                     14       1       0.0       0                     0
# 15816                     26       2       0.0       0                     0
# 52217                     16       1       0.0       0                     1
# 12518                     14       1       0.0       0                     0
# 31811                     30       2       0.0       0                     0
#
#        StaysInWeekNights       Meal  MarketSegment DistributionChannel  \
# 16300                  2         BB         Groups               TA/TO
# 942                    2         BB  Offline TA/TO               TA/TO
# 329                    2         HB  Offline TA/TO               TA/TO
# 9250                   2         BB         Groups               TA/TO
# 3897                   2         HB  Offline TA/TO               TA/TO
# 2809                   2         HB  Offline TA/TO               TA/TO
# 21367                  3         BB         Groups               TA/TO
# 31039                  2         BB         Groups               TA/TO
# 9647                   1         BB  Offline TA/TO               TA/TO
# 24288                  1         BB         Groups               TA/TO
# 12923                  2         BB  Offline TA/TO               TA/TO
# 12560                  2         BB  Offline TA/TO               TA/TO
# 2326                   2         BB  Offline TA/TO               TA/TO
# 15752                  2         BB         Groups               TA/TO
# 28970                  3         BB         Groups               TA/TO
# 24955                  1         BB      Corporate           Corporate
# 15816                  3         BB         Groups               TA/TO
# 52217                  2  Undefined         Groups              Direct
# 12518                  3         BB  Offline TA/TO               TA/TO
# 31811                  2         BB         Groups               TA/TO
#
#       ReservedRoomType DepositType     CustomerType  rows  cancellation_rate  \
# 16300                A  Non Refund        Transient   210           1.000000
# 942                  A  Non Refund        Transient   160           1.000000
# 329                  A  No Deposit  Transient-Party   155           0.658065
# 9250                 A  Non Refund        Transient   150           1.000000
# 3897                 A  Non Refund  Transient-Party   125           1.000000
# 2809                 A  Non Refund  Transient-Party   122           1.000000
# 21367                A  Non Refund        Transient   120           1.000000
# 31039                A  Non Refund        Transient   120           1.000000
# 9647                 A  No Deposit  Transient-Party   119           0.865546
# 24288                A  No Deposit  Transient-Party   117           0.504274
# 12923                A  No Deposit  Transient-Party   114           0.140351
# 12560                A  Non Refund        Transient   110           1.000000
# 2326                 A  No Deposit  Transient-Party   108           0.092593
# 15752                A  Non Refund        Transient   101           1.000000
# 28970                A  Non Refund        Transient   100           1.000000
# 24955                A  Non Refund        Transient   100           1.000000
# 15816                A  No Deposit  Transient-Party   100           0.020000
# 52217                A  No Deposit  Transient-Party    99           0.151515
# 12518                A  Non Refund        Transient    90           1.000000
# 31811                A  Non Refund        Transient    89           1.000000
#
#        distinct_agents  distinct_companies
# 16300                1                   0
# 942                  1                   0
# 329                  1                   0
# 9250                 1                   0
# 3897                 1                   0
# 2809                 1                   0
# 21367                2                   0
# 31039                0                   0
# 9647                 1                   0
# 24288                1                   0
# 12923                1                   0
# 12560                1                   0
# 2326                 1                   0
# 15752                1                   0
# 28970                0                   0
# 24955                0                   1
# 15816                1                   0
# 52217                0                   0
# 12518                1                   0
# 31811                1                   0

# %% [markdown]
# La presencia de coincidencias se documenta como una limitación de identificación. Antes de decidir una deduplicación será necesario analizar el tamaño de los grupos, la existencia de resultados contradictorios y su relación con reservas grupales. El EDA conserva todas las filas.

# %% [markdown]
# ## Influencia de las repeticiones sobre la cancelación
#
# Se compara el comportamiento de las filas que aparecen una sola vez con el de aquellas que pertenecen a una combinación completamente repetida. Esta separación no afirma que las reservas repetidas sean copias inválidas: permite medir cuánto influyen los bloques coincidentes sobre la distribución del target.

# %%
duplicate_comparison_df = bookings_df.copy()
duplicate_comparison_df["RepetitionGroup"] = np.where(
    exact_duplicate_mask,
    "Exact repeated combination",
    "Unique combination",
)

duplicate_target_summary = (
    duplicate_comparison_df.groupby("RepetitionGroup")
    .agg(
        rows=("IsCanceled", "size"),
        cancellations=("IsCanceled", "sum"),
        cancellation_rate=("IsCanceled", "mean"),
    )
    .reset_index()
)
duplicate_target_summary["dataset_percentage"] = (
    duplicate_target_summary["rows"] / len(bookings_df) * 100
)
duplicate_target_summary["cancellation_share"] = (
    duplicate_target_summary["cancellations"]
    / bookings_df["IsCanceled"].sum() * 100
)
display(duplicate_target_summary)
# Out:
#               RepetitionGroup   rows  cancellations  cancellation_rate  \
# 0  Exact repeated combination  40165          23451           0.583867
# 1          Unique combination  79225          20773           0.262203
#
#    dataset_percentage  cancellation_share
# 0           33.641846           53.027768
# 1           66.358154           46.972232

# %% [markdown]
# ### Comparación por contexto comercial
#
# La tasa se desglosa por variables centrales para comprobar si la diferencia se debe únicamente a que las repeticiones se concentran en determinados hoteles, segmentos o condiciones de depósito.

# %%
duplicate_comparison_columns = [
    "HotelType", "DepositType", "MarketSegment", "CustomerType"
]

for column in duplicate_comparison_columns:
    comparison = (
        duplicate_comparison_df.groupby([column, "RepetitionGroup"], dropna=False)
        .agg(
            rows=("IsCanceled", "size"),
            cancellation_rate=("IsCanceled", "mean"),
        )
        .reset_index()
    )
    comparison["within_category_percentage"] = (
        comparison["rows"]
        / comparison.groupby(column, dropna=False)["rows"].transform("sum")
        * 100
    )
    print(column)
    display(comparison)
# Out:
# HotelType
#       HotelType             RepetitionGroup   rows  cancellation_rate  \
# 0    City Hotel  Exact repeated combination  31748           0.613172
# 1    City Hotel          Unique combination  47582           0.286558
# 2  Resort Hotel  Exact repeated combination   8417           0.473328
# 3  Resort Hotel          Unique combination  31643           0.225579
#
#    within_category_percentage
# 0                   40.020169
# 1                   59.979831
# 2                   21.010984
# 3                   78.989016
# DepositType
#   DepositType             RepetitionGroup   rows  cancellation_rate  \
# 0  No Deposit  Exact repeated combination  25773           0.355605
# 1  No Deposit          Unique combination  78868           0.260296
# 2  Non Refund  Exact repeated combination  14316           0.996927
# 3  Non Refund          Unique combination    271           0.819188
# 4  Refundable  Exact repeated combination     76           0.184211
# 5  Refundable          Unique combination     86           0.255814
#
#    within_category_percentage
# 0                   24.629925
# 1                   75.370075
# 2                   98.142181
# 3                    1.857819
# 4                   46.913580
# 5                   53.086420
# MarketSegment
#     MarketSegment             RepetitionGroup   rows  cancellation_rate  \
# 0        Aviation  Exact repeated combination     19           0.684211
# 1        Aviation          Unique combination    218           0.178899
# 2   Complementary  Exact repeated combination     75           0.200000
# 3   Complementary          Unique combination    668           0.122754
# 4       Corporate  Exact repeated combination   1474           0.379919
# 5       Corporate          Unique combination   3821           0.113059
# 6          Direct  Exact repeated combination   1405           0.238434
# 7          Direct          Unique combination  11201           0.142755
# 8          Groups  Exact repeated combination  16713           0.695267
# 9          Groups          Unique combination   3098           0.153970
# 10  Offline TA/TO  Exact repeated combination  12210           0.558477
# 11  Offline TA/TO          Unique combination  12009           0.124240
# 12      Online TA  Exact repeated combination   8269           0.494498
# 13      Online TA          Unique combination  48208           0.345378
# 14      Undefined          Unique combination      2           1.000000
#
#     within_category_percentage
# 0                     8.016878
# 1                    91.983122
# 2                    10.094213
# 3                    89.905787
# 4                    27.837583
# 5                    72.162417
# 6                    11.145486
# 7                    88.854514
# 8                    84.362223
# 9                    15.637777
# 10                   50.414963
# 11                   49.585037
# 12                   14.641358
# 13                   85.358642
# 14                  100.000000
# CustomerType
#       CustomerType             RepetitionGroup   rows  cancellation_rate  \
# 0         Contract  Exact repeated combination   1188           0.709596
# 1         Contract          Unique combination   2888           0.145083
# 2            Group  Exact repeated combination     57           0.122807
# 3            Group          Unique combination    520           0.100000
# 4        Transient  Exact repeated combination  22209           0.776892
# 5        Transient          Unique combination  67404           0.285740
# 6  Transient-Party  Exact repeated combination  16711           0.319969
# 7  Transient-Party          Unique combination   8413           0.123856
#
#    within_category_percentage
# 0                   29.146222
# 1                   70.853778
# 2                    9.878683
# 3                   90.121317
# 4                   24.783235
# 5                   75.216765
# 6                   66.514090
# 7                   33.485910

# %% [markdown]
# ### Tamaño de la combinación repetida
#
# Se asigna a cada fila el número de veces que aparece su combinación exacta. Luego se compara la cancelación por intervalos de tamaño para saber si los bloques más grandes presentan un comportamiento especialmente diferente.

# %%
exact_group_ids = bookings_df.groupby(
    bookings_df.columns.tolist(), dropna=False, sort=False
).ngroup()
exact_group_sizes = exact_group_ids.map(exact_group_ids.value_counts())

duplicate_comparison_df["ExactGroupId"] = exact_group_ids
duplicate_comparison_df["ExactGroupSize"] = exact_group_sizes
duplicate_comparison_df["ExactGroupSizeBand"] = pd.cut(
    exact_group_sizes,
    bins=[0, 1, 2, 5, 10, 25, 50, np.inf],
    labels=["1", "2", "3-5", "6-10", "11-25", "26-50", ">50"],
)

duplicate_size_summary = (
    duplicate_comparison_df.groupby("ExactGroupSizeBand", observed=True)
    .agg(
        rows=("IsCanceled", "size"),
        exact_combinations=("ExactGroupId", "nunique"),
        cancellation_rate=("IsCanceled", "mean"),
    )
    .reset_index()
)
duplicate_size_summary["dataset_percentage"] = (
    duplicate_size_summary["rows"] / len(bookings_df) * 100
)
display(duplicate_size_summary)
# Out:
#   ExactGroupSizeBand   rows  exact_combinations  cancellation_rate  \
# 0                  1  79225               79225           0.262203
# 1                  2  10068                5034           0.341677
# 2                3-5   6270                1741           0.378150
# 3               6-10   4722                 605           0.493011
# 4              11-25   9688                 567           0.760219
# 5              26-50   5798                 175           0.774060
# 6                >50   3619                  49           0.955789
#
#    dataset_percentage
# 0           66.358154
# 1            8.432867
# 2            5.251696
# 3            3.955105
# 4            8.114582
# 5            4.856353
# 6            3.031242

# %% [markdown]
# ### Comparación hipotética con una versión deduplicada
#
# Esta simulación conserva una sola fila por combinación exacta únicamente para medir el cambio en la distribución. No reemplaza `bookings_df` ni constituye todavía una decisión de preparación.

# %%
hypothetical_deduplicated_df = bookings_df.drop_duplicates().copy()

deduplication_effect_summary = pd.DataFrame(
    {
        "dataset": ["Original", "One row per exact combination"],
        "rows": [len(bookings_df), len(hypothetical_deduplicated_df)],
        "cancellations": [
            bookings_df["IsCanceled"].sum(),
            hypothetical_deduplicated_df["IsCanceled"].sum(),
        ],
        "cancellation_rate": [
            bookings_df["IsCanceled"].mean(),
            hypothetical_deduplicated_df["IsCanceled"].mean(),
        ],
    }
)
display(deduplication_effect_summary)

deduplication_by_hotel = pd.concat(
    [
        bookings_df.groupby("HotelType")["IsCanceled"]
        .agg(rows="size", cancellation_rate="mean")
        .assign(dataset="Original"),
        hypothetical_deduplicated_df.groupby("HotelType")["IsCanceled"]
        .agg(rows="size", cancellation_rate="mean")
        .assign(dataset="One row per exact combination"),
    ]
).reset_index()
display(deduplication_by_hotel)
# Out:
#                          dataset    rows  cancellations  cancellation_rate
# 0                       Original  119390          44224           0.370416
# 1  One row per exact combination   87396          24025           0.274898
#       HotelType   rows  cancellation_rate                        dataset
# 0    City Hotel  79330           0.417270                       Original
# 1  Resort Hotel  40060           0.277634                       Original
# 2    City Hotel  53428           0.300386  One row per exact combination
# 3  Resort Hotel  33968           0.234809  One row per exact combination

# %% [markdown]
# La comparación permite cuantificar el efecto de las repeticiones, pero no resuelve por sí sola si representan observaciones válidas. La decisión posterior deberá considerar tanto la unidad de análisis —cada reserva— como el riesgo de que combinaciones idénticas aparezcan simultáneamente en entrenamiento y validación.

# %% [markdown]
# ## Coincidencias según el momento de predicción
#
# La definición de una reserva repetida depende de la información disponible cuando se calcula el riesgo. Se comparan dos escenarios. El primero representa una reserva ya confirmada y registrada, por lo que `DaysInWaitingList` está disponible, pero excluye campos que todavía pueden modificarse. El segundo representa una fotografía operativa más cercana a la llegada e incorpora esos campos, aunque el dataset no permite conocer con precisión cuándo alcanzaron su valor registrado.

# %% [markdown]
# ### Escenarios considerados
#
# **Reserva confirmada y registrada:** se excluyen el target, el estado final, la fecha del estado, la habitación finalmente asignada y los cambios acumulados. `DaysInWaitingList` está disponible porque, según la definición original, mide la espera transcurrida antes de confirmar la reserva al cliente.
#
# **Momento operativo previo a la llegada:** se excluyen únicamente el target y sus variables de resultado. Se permite utilizar `AssignedRoomType`, `BookingChanges` y `DaysInWaitingList` como una fotografía operativa. Este escenario sólo sería válido si el hotel pudiera garantizar que esos valores ya están disponibles al ejecutar el modelo.

# %%
result_columns = [
    "IsCanceled", "ReservationStatus", "ReservationStatusDate"
]
post_booking_columns = [
    "AssignedRoomType", "BookingChanges"
]

prediction_moment_columns = {
    "Confirmed booking": [
        column for column in bookings_df.columns
        if column not in [*result_columns, *post_booking_columns]
    ],
    "Pre-arrival operational snapshot": [
        column for column in bookings_df.columns
        if column not in result_columns
    ],
}

display(
    pd.DataFrame(
        {
            "prediction_moment": prediction_moment_columns.keys(),
            "signature_columns": prediction_moment_columns.values(),
            "column_count": [
                len(columns) for columns in prediction_moment_columns.values()
            ],
        }
    )
)
# Out:
#                   prediction_moment  \
# 0                 Confirmed booking
# 1  Pre-arrival operational snapshot
#
#                                    signature_columns  column_count
# 0  [HotelType, LeadTime, ArrivalDateYear, Arrival...            27
# 1  [HotelType, LeadTime, ArrivalDateYear, Arrival...            29

# %%
prediction_moment_records = []
prediction_moment_group_ids = {}

for moment, signature_columns in prediction_moment_columns.items():
    group_ids = bookings_df.groupby(
        signature_columns, dropna=False, sort=False
    ).ngroup()
    group_sizes = group_ids.map(group_ids.value_counts())
    repeated_mask = group_sizes.gt(1)

    group_target_summary = (
        pd.DataFrame(
            {
                "group_id": group_ids,
                "IsCanceled": bookings_df["IsCanceled"],
            }
        )
        .groupby("group_id")
        .agg(
            rows=("IsCanceled", "size"),
            target_values=("IsCanceled", "nunique"),
            cancellation_rate=("IsCanceled", "mean"),
        )
    )
    repeated_groups = group_target_summary.loc[
        group_target_summary["rows"].gt(1)
    ]
    conflicting_groups = repeated_groups.loc[
        repeated_groups["target_values"].gt(1)
    ]

    prediction_moment_group_ids[moment] = group_ids
    prediction_moment_records.append(
        {
            "prediction_moment": moment,
            "signature_columns": len(signature_columns),
            "total_groups": len(group_target_summary),
            "repeated_groups": len(repeated_groups),
            "rows_in_repeated_groups": repeated_mask.sum(),
            "repeated_rows_percentage": repeated_mask.mean() * 100,
            "largest_group": group_sizes.max(),
            "conflicting_groups": len(conflicting_groups),
            "rows_in_conflicting_groups": conflicting_groups["rows"].sum(),
        }
    )

prediction_moment_summary = pd.DataFrame(prediction_moment_records)
display(prediction_moment_summary)
# Out:
#                   prediction_moment  signature_columns  total_groups  \
# 0                 Confirmed booking                 27         85039
# 1  Pre-arrival operational snapshot                 29         86873
#
#    repeated_groups  rows_in_repeated_groups  repeated_rows_percentage  \
# 0             8516                    42867                 35.905017
# 1             8237                    40754                 34.135187
#
#    largest_group  conflicting_groups  rows_in_conflicting_groups
# 0            180                 301                        2202
# 1            180                 265                        1812

# %% [markdown]
# ### Cancelación de combinaciones únicas y repetidas por escenario
#
# Se comprueba si la asociación entre repetición y cancelación se mantiene al definir la firma con información disponible en cada momento.

# %%
prediction_moment_target_records = []

for moment, group_ids in prediction_moment_group_ids.items():
    group_sizes = group_ids.map(group_ids.value_counts())
    repetition_label = np.where(
        group_sizes.gt(1), "Repeated signature", "Unique signature"
    )
    moment_comparison = (
        pd.DataFrame(
            {
                "repetition_status": repetition_label,
                "IsCanceled": bookings_df["IsCanceled"],
            }
        )
        .groupby("repetition_status")
        .agg(
            rows=("IsCanceled", "size"),
            cancellation_rate=("IsCanceled", "mean"),
        )
        .reset_index()
    )
    moment_comparison.insert(0, "prediction_moment", moment)
    prediction_moment_target_records.append(moment_comparison)

prediction_moment_target_summary = pd.concat(
    prediction_moment_target_records, ignore_index=True
)
display(prediction_moment_target_summary)
# Out:
#                   prediction_moment   repetition_status   rows  \
# 0                 Confirmed booking  Repeated signature  42867
# 1                 Confirmed booking    Unique signature  76523
# 2  Pre-arrival operational snapshot  Repeated signature  40754
# 3  Pre-arrival operational snapshot    Unique signature  78636
#
#    cancellation_rate
# 0           0.562951
# 1           0.262562
# 2           0.586372
# 3           0.258495

# %% [markdown]
# Para la evaluación principal, la firma correspondiente a la reserva confirmada es la candidata inicial para mantener observaciones relacionadas dentro del mismo fold. La firma definitiva deberá revisarse después de seleccionar las variables admisibles para el modelo.

# %% [markdown]
# ## Distribución de la variable objetivo
#
# La variable `IsCanceled` identifica si una reserva fue cancelada (`1`) o no cancelada (`0`). Antes de estudiar su relación con otras variables se analiza el balance global de ambas clases.

# %%
target_labels = {0: "No cancelada", 1: "Cancelada"}
target_distribution = (
    bookings_df["IsCanceled"]
    .value_counts()
    .sort_index()
    .rename_axis("IsCanceled")
    .reset_index(name="rows")
)
target_distribution["booking_status"] = (
    target_distribution["IsCanceled"].map(target_labels)
)
target_distribution["percentage"] = (
    target_distribution["rows"] / len(bookings_df) * 100
)

display(
    target_distribution[["IsCanceled", "booking_status", "rows", "percentage"]]
)

majority_rows = target_distribution["rows"].max()
minority_rows = target_distribution["rows"].min()
print(f"Relación entre la clase mayoritaria y minoritaria: {majority_rows / minority_rows:.2f}:1")
# Out:
#    IsCanceled booking_status   rows  percentage
# 0           0   No cancelada  75166   62.958372
# 1           1      Cancelada  44224   37.041628
# Relación entre la clase mayoritaria y minoritaria: 1.70:1

# %% [markdown]
# ### Representación gráfica
#
# La gráfica presenta simultáneamente la frecuencia absoluta y el porcentaje de cada clase. Si el notebook se ejecuta dentro del repositorio, se guarda una copia en alta resolución para su posterior incorporación al informe.

# %%
figure, axis = plt.subplots(figsize=(8, 5.5))
bars = axis.bar(
    target_distribution["booking_status"],
    target_distribution["rows"],
    color=["#4C78A8", "#E45756"],
    width=0.65,
)

for bar, row in zip(bars, target_distribution.itertuples()):
    axis.annotate(
        f"{row.rows:,}\n({row.percentage:.1f} %)",
        xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()),
        xytext=(0, 6),
        textcoords="offset points",
        ha="center",
        va="bottom",
        fontsize=11,
    )

axis.set_title("Distribución de reservas según su estado de cancelación")
axis.set_xlabel("Estado de la reserva")
axis.set_ylabel("Cantidad de reservas")
axis.set_ylim(0, target_distribution["rows"].max() * 1.15)
sns.despine(ax=axis)
figure.tight_layout()

if PROJECT_ROOT is not None:
    figures_dir = PROJECT_ROOT / "outputs" / "figures"
    figures_dir.mkdir(parents=True, exist_ok=True)
    target_figure_path = figures_dir / "eda_target_distribution.png"
    figure.savefig(target_figure_path, dpi=300, bbox_inches="tight")
    print(f"Gráfica guardada en: {target_figure_path}")

plt.show()
# Out:
# Gráfica guardada en: C:\Code\Vialesoft\Vialesoft_Devlab\Mini_Proyectos\Machine_Learning\Obligatorio2026\outputs\figures\eda_target_distribution.png

# %% [markdown]
# La clase no cancelada es mayoritaria, pero la proporción de cancelaciones es suficientemente grande como para representar un fenómeno frecuente del negocio. El desbalance deberá considerarse al seleccionar las métricas y construir la validación, aunque no es tan extremo como para justificar por sí solo técnicas de remuestreo. La decisión se evaluará posteriormente dentro del proceso de modelado.

# %% [markdown]
# ## Distribución y cancelación por hotel
#
# Los datasets integrados representan dos establecimientos diferentes. Se comparan tanto su volumen de reservas como su tasa de cancelación. Esta distinción evita atribuir a un mayor riesgo lo que podría explicarse únicamente por una mayor cantidad de operaciones.

# %%
hotel_target_summary = (
    bookings_df.groupby("HotelType")
    .agg(
        reservations=("IsCanceled", "size"),
        cancellations=("IsCanceled", "sum"),
        cancellation_rate=("IsCanceled", "mean"),
    )
    .reset_index()
)
hotel_target_summary["not_canceled"] = (
    hotel_target_summary["reservations"]
    - hotel_target_summary["cancellations"]
)
hotel_target_summary["dataset_percentage"] = (
    hotel_target_summary["reservations"] / len(bookings_df) * 100
)
hotel_target_summary["cancellation_percentage"] = (
    hotel_target_summary["cancellation_rate"] * 100
)

display(hotel_target_summary)
# Out:
#       HotelType  reservations  cancellations  cancellation_rate  not_canceled  \
# 0    City Hotel         79330          33102           0.417270         46228
# 1  Resort Hotel         40060          11122           0.277634         28938
#
#    dataset_percentage  cancellation_percentage
# 0           66.446101                41.726963
# 1           33.553899                27.763355

# %% [markdown]
# ### Comparación gráfica
#
# El primer panel representa el volumen total de reservas y el segundo la proporción cancelada dentro de cada hotel. La línea discontinua indica la tasa global del dataset.

# %%
hotel_colors = {
    "City Hotel": "#4C78A8",
    "Resort Hotel": "#F2A541",
}
hotel_order = hotel_target_summary.sort_values(
    "reservations", ascending=False
)["HotelType"].tolist()
plot_data = hotel_target_summary.set_index("HotelType").loc[hotel_order].reset_index()

figure, axes = plt.subplots(1, 2, figsize=(14, 5.5))

volume_bars = axes[0].bar(
    plot_data["HotelType"],
    plot_data["reservations"],
    color=[hotel_colors[hotel] for hotel in plot_data["HotelType"]],
)
for bar, value in zip(volume_bars, plot_data["reservations"]):
    axes[0].annotate(
        f"{value:,}",
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),
        xytext=(0, 5), textcoords="offset points",
        ha="center", va="bottom",
    )
axes[0].set_title("Volumen de reservas por hotel")
axes[0].set_xlabel("Tipo de hotel")
axes[0].set_ylabel("Cantidad de reservas")
axes[0].set_ylim(0, plot_data["reservations"].max() * 1.15)

rate_bars = axes[1].bar(
    plot_data["HotelType"],
    plot_data["cancellation_percentage"],
    color=[hotel_colors[hotel] for hotel in plot_data["HotelType"]],
)
for bar, value in zip(rate_bars, plot_data["cancellation_percentage"]):
    axes[1].annotate(
        f"{value:.1f} %",
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),
        xytext=(0, 5), textcoords="offset points",
        ha="center", va="bottom",
    )
global_cancellation_percentage = bookings_df["IsCanceled"].mean() * 100
axes[1].axhline(
    global_cancellation_percentage,
    color="#555555", linestyle="--", linewidth=1.5,
    label=f"Promedio global ({global_cancellation_percentage:.1f} %)",
)
axes[1].set_title("Tasa de cancelación por hotel")
axes[1].set_xlabel("Tipo de hotel")
axes[1].set_ylabel("Reservas canceladas (%)")
axes[1].set_ylim(0, max(plot_data["cancellation_percentage"].max() * 1.2, 50))
axes[1].legend()

for axis in axes:
    sns.despine(ax=axis)

figure.suptitle("Volumen y cancelación según el tipo de hotel", fontsize=15)
figure.tight_layout()

if PROJECT_ROOT is not None:
    figures_dir = PROJECT_ROOT / "outputs" / "figures"
    figures_dir.mkdir(parents=True, exist_ok=True)
    hotel_figure_path = figures_dir / "eda_cancellation_by_hotel.png"
    figure.savefig(hotel_figure_path, dpi=300, bbox_inches="tight")
    print(f"Gráfica guardada en: {hotel_figure_path}")

plt.show()
# Out:
# Gráfica guardada en: C:\Code\Vialesoft\Vialesoft_Devlab\Mini_Proyectos\Machine_Learning\Obligatorio2026\outputs\figures\eda_cancellation_by_hotel.png

# %% [markdown]
# La diferencia observada debe interpretarse dentro del alcance del dataset: se comparan dos establecimientos concretos y no todos los hoteles urbanos y vacacionales. En consecuencia, `HotelType` también identifica el origen de cada archivo y puede resumir diferencias operativas, comerciales y geográficas no observadas directamente.

# %% [markdown]
# ## Cobertura y evolución temporal
#
# La fecha de llegada se reconstruye a partir del año, mes y día para validar el calendario y estudiar la evolución mensual. El objetivo es detectar cambios de volumen, estacionalidad y posibles variaciones temporales en la cancelación.

# %%
month_number = {
    month: number
    for number, month in enumerate(
        [
            "January", "February", "March", "April",
            "May", "June", "July", "August",
            "September", "October", "November", "December",
        ],
        start=1,
    )
}

arrival_dates = pd.to_datetime(
    {
        "year": bookings_df["ArrivalDateYear"],
        "month": bookings_df["ArrivalDateMonth"].map(month_number),
        "day": bookings_df["ArrivalDateDayOfMonth"],
    },
    errors="coerce",
)
invalid_arrival_dates = arrival_dates.isna()

print(f"Fechas de llegada inválidas: {invalid_arrival_dates.sum():,}")
if invalid_arrival_dates.any():
    display(
        bookings_df.loc[
            invalid_arrival_dates,
            ["ArrivalDateYear", "ArrivalDateMonth", "ArrivalDateDayOfMonth"],
        ]
    )

arrival_months = arrival_dates.dt.to_period("M").dt.to_timestamp()
# Out:
# Fechas de llegada inválidas: 0

# %% [markdown]
# ### Cobertura del período
#
# Se informa el primer y último mes observado y la cantidad de meses con registros. Los años ubicados en los extremos del período pueden estar incompletos y no deben compararse directamente mediante sus totales anuales.

# %%
temporal_analysis_df = bookings_df.assign(
    ArrivalDate=arrival_dates,
    ArrivalMonth=arrival_months,
)

temporal_coverage_summary = (
    temporal_analysis_df.groupby("HotelType")
    .agg(
        first_arrival=("ArrivalDate", "min"),
        last_arrival=("ArrivalDate", "max"),
        observed_months=("ArrivalMonth", "nunique"),
        reservations=("IsCanceled", "size"),
    )
    .reset_index()
)
display(temporal_coverage_summary)

year_coverage_summary = (
    temporal_analysis_df.groupby(["HotelType", "ArrivalDateYear"])
    .agg(
        observed_months=("ArrivalMonth", "nunique"),
        first_month=("ArrivalMonth", "min"),
        last_month=("ArrivalMonth", "max"),
        reservations=("IsCanceled", "size"),
        cancellation_rate=("IsCanceled", "mean"),
    )
    .reset_index()
)
year_coverage_summary["cancellation_percentage"] = (
    year_coverage_summary["cancellation_rate"] * 100
)
display(year_coverage_summary)
# Out:
#       HotelType first_arrival last_arrival  observed_months  reservations
# 0    City Hotel    2015-07-01   2017-08-31               26         79330
# 1  Resort Hotel    2015-07-01   2017-08-31               26         40060
#       HotelType  ArrivalDateYear  observed_months first_month last_month  \
# 0    City Hotel             2015                6  2015-07-01 2015-12-01
# 1    City Hotel             2016               12  2016-01-01 2016-12-01
# 2    City Hotel             2017                8  2017-01-01 2017-08-01
# 3  Resort Hotel             2015                6  2015-07-01 2015-12-01
# 4  Resort Hotel             2016               12  2016-01-01 2016-12-01
# 5  Resort Hotel             2017                8  2017-01-01 2017-08-01
#
#    reservations  cancellation_rate  cancellation_percentage
# 0         13682           0.438825                43.882473
# 1         38140           0.403959                40.395910
# 2         27508           0.425004                42.500364
# 3          8314           0.257157                25.715660
# 4         18567           0.265525                26.552486
# 5         13179           0.307611                30.761059

# %% [markdown]
# ### Evolución mensual por hotel
#
# El volumen y la tasa de cancelación se representan por mes calendario. Se mantienen separados porque un pico en la cantidad de cancelaciones puede estar causado por un aumento general de reservas.

# %%
monthly_hotel_summary = (
    temporal_analysis_df.groupby(["ArrivalMonth", "HotelType"])
    .agg(
        reservations=("IsCanceled", "size"),
        cancellations=("IsCanceled", "sum"),
        cancellation_rate=("IsCanceled", "mean"),
    )
    .reset_index()
)
monthly_hotel_summary["cancellation_percentage"] = (
    monthly_hotel_summary["cancellation_rate"] * 100
)
display(monthly_hotel_summary.head(12))
# Out:
#    ArrivalMonth     HotelType  reservations  cancellations  cancellation_rate  \
# 0    2015-07-01    City Hotel          1398            939           0.671674
# 1    2015-07-01  Resort Hotel          1378            320           0.232221
# 2    2015-08-01    City Hotel          2480           1232           0.496774
# 3    2015-08-01  Resort Hotel          1409            366           0.259759
# 4    2015-09-01    City Hotel          3529           1543           0.437234
# 5    2015-09-01  Resort Hotel          1585            551           0.347634
# 6    2015-10-01    City Hotel          3386           1321           0.390136
# 7    2015-10-01  Resort Hotel          1571            411           0.261617
# 8    2015-11-01    City Hotel          1235            301           0.243725
# 9    2015-11-01  Resort Hotel          1105            185           0.167421
# 10   2015-12-01    City Hotel          1654            668           0.403869
# 11   2015-12-01  Resort Hotel          1266            305           0.240916
#
#     cancellation_percentage
# 0                 67.167382
# 1                 23.222061
# 2                 49.677419
# 3                 25.975869
# 4                 43.723434
# 5                 34.763407
# 6                 39.013585
# 7                 26.161680
# 8                 24.372470
# 9                 16.742081
# 10                40.386941
# 11                24.091627

# %%
figure, axes = plt.subplots(2, 1, figsize=(15, 10), sharex=True)

sns.lineplot(
    data=monthly_hotel_summary,
    x="ArrivalMonth", y="reservations", hue="HotelType",
    palette=hotel_colors, marker="o", ax=axes[0],
)
axes[0].set_title("Volumen mensual de reservas")
axes[0].set_xlabel("")
axes[0].set_ylabel("Cantidad de reservas")
axes[0].legend(title="Hotel")

sns.lineplot(
    data=monthly_hotel_summary,
    x="ArrivalMonth", y="cancellation_percentage", hue="HotelType",
    palette=hotel_colors, marker="o", ax=axes[1],
)
axes[1].axhline(
    bookings_df["IsCanceled"].mean() * 100,
    color="#555555", linestyle="--", linewidth=1.2,
    label="Promedio global",
)
axes[1].set_title("Tasa mensual de cancelación")
axes[1].set_xlabel("Mes de llegada")
axes[1].set_ylabel("Reservas canceladas (%)")
axes[1].legend(title="Hotel")

for axis in axes:
    sns.despine(ax=axis)
    axis.grid(axis="x", alpha=0.25)

figure.suptitle("Evolución temporal de las reservas y cancelaciones", fontsize=16)
figure.autofmt_xdate(rotation=45)
figure.tight_layout()

if PROJECT_ROOT is not None:
    figures_dir = PROJECT_ROOT / "outputs" / "figures"
    figures_dir.mkdir(parents=True, exist_ok=True)
    temporal_figure_path = figures_dir / "eda_monthly_booking_evolution.png"
    figure.savefig(temporal_figure_path, dpi=300, bbox_inches="tight")
    print(f"Gráfica guardada en: {temporal_figure_path}")

plt.show()
# Out:
# Gráfica guardada en: C:\Code\Vialesoft\Vialesoft_Devlab\Mini_Proyectos\Machine_Learning\Obligatorio2026\outputs\figures\eda_monthly_booking_evolution.png

# %% [markdown]
# El período observado comienza en 2015 y termina en 2017, pero los años extremos no contienen necesariamente los doce meses. Por ello, los totales anuales no se interpretarán como crecimiento o caída sin considerar su cobertura. Las variaciones mensuales también pueden estar afectadas por bloques de reservas repetidas, por lo que cualquier patrón temporal deberá contrastarse posteriormente con la estrategia de validación.

# %% [markdown]
# ## Estacionalidad por mes calendario
#
# Las observaciones de los distintos años se agrupan por mes calendario para buscar patrones estacionales. Como la cobertura no es uniforme, el volumen se divide por la cantidad de años en los que cada mes está presente. Las tasas agregadas se comparan además con 2016, el único año completo, para comprobar si el patrón general depende de los años parciales.

# %%
month_order = list(month_number.keys())
seasonality_df = temporal_analysis_df.assign(
    CalendarMonth=pd.Categorical(
        temporal_analysis_df["ArrivalDateMonth"],
        categories=month_order,
        ordered=True,
    )
)

monthly_seasonality_summary = (
    seasonality_df.groupby(["CalendarMonth", "HotelType"], observed=True)
    .agg(
        reservations=("IsCanceled", "size"),
        cancellations=("IsCanceled", "sum"),
        cancellation_rate=("IsCanceled", "mean"),
        observed_years=("ArrivalDateYear", "nunique"),
    )
    .reset_index()
)
monthly_seasonality_summary["average_reservations_per_observed_year"] = (
    monthly_seasonality_summary["reservations"]
    / monthly_seasonality_summary["observed_years"]
)
monthly_seasonality_summary["cancellation_percentage"] = (
    monthly_seasonality_summary["cancellation_rate"] * 100
)
display(monthly_seasonality_summary)
# Out:
#    CalendarMonth     HotelType  reservations  cancellations  \
# 0        January    City Hotel          3736           1482
# 1        January  Resort Hotel          2193            325
# 2       February    City Hotel          4965           1901
# 3       February  Resort Hotel          3103            795
# 4          March    City Hotel          6458           2386
# 5          March  Resort Hotel          3336            763
# 6          April    City Hotel          7480           3465
# 7          April  Resort Hotel          3609           1059
# 8            May    City Hotel          8232           3653
# 9            May  Resort Hotel          3559           1024
# 10          June    City Hotel          7894           3528
# 11          June  Resort Hotel          3045           1007
# 12          July    City Hotel          8088           3306
# 13          July  Resort Hotel          4573           1436
# 14        August    City Hotel          8983           3602
# 15        August  Resort Hotel          4894           1637
# 16     September    City Hotel          7400           3110
# 17     September  Resort Hotel          3108           1006
# 18       October    City Hotel          7605           3268
# 19       October  Resort Hotel          3555            978
# 20      November    City Hotel          4357           1661
# 21      November  Resort Hotel          2437            461
# 22      December    City Hotel          4132           1740
# 23      December  Resort Hotel          2648            631
#
#     cancellation_rate  observed_years  average_reservations_per_observed_year  \
# 0            0.396681               2                             1868.000000
# 1            0.148199               2                             1096.500000
# 2            0.382880               2                             2482.500000
# 3            0.256204               2                             1551.500000
# 4            0.369464               2                             3229.000000
# 5            0.228717               2                             1668.000000
# 6            0.463235               2                             3740.000000
# 7            0.293433               2                             1804.500000
# 8            0.443756               2                             4116.000000
# 9            0.287721               2                             1779.500000
# 10           0.446922               2                             3947.000000
# 11           0.330706               2                             1522.500000
# 12           0.408754               3                             2696.000000
# 13           0.314017               3                             1524.333333
# 14           0.400980               3                             2994.333333
# 15           0.334491               3                             1631.333333
# 16           0.420270               2                             3700.000000
# 17           0.323681               2                             1554.000000
# 18           0.429717               2                             3802.500000
# 19           0.275105               2                             1777.500000
# 20           0.381226               2                             2178.500000
# 21           0.189167               2                             1218.500000
# 22           0.421104               2                             2066.000000
# 23           0.238293               2                             1324.000000
#
#     cancellation_percentage
# 0                 39.668094
# 1                 14.819881
# 2                 38.288016
# 3                 25.620367
# 4                 36.946423
# 5                 22.871703
# 6                 46.323529
# 7                 29.343308
# 8                 44.375607
# 9                 28.772127
# 10                44.692171
# 11                33.070608
# 12                40.875371
# 13                31.401706
# 14                40.097963
# 15                33.449121
# 16                42.027027
# 17                32.368082
# 18                42.971729
# 19                27.510549
# 20                38.122561
# 21                18.916701
# 22                42.110358
# 23                23.829305

# %%
figure, axes = plt.subplots(2, 1, figsize=(15, 10), sharex=True)

sns.lineplot(
    data=monthly_seasonality_summary,
    x="CalendarMonth", y="average_reservations_per_observed_year",
    hue="HotelType", palette=hotel_colors, marker="o", ax=axes[0],
)
axes[0].set_title("Volumen mensual medio por año observado")
axes[0].set_xlabel("")
axes[0].set_ylabel("Reservas medias")
axes[0].legend(title="Hotel")

sns.lineplot(
    data=monthly_seasonality_summary,
    x="CalendarMonth", y="cancellation_percentage",
    hue="HotelType", palette=hotel_colors, marker="o", ax=axes[1],
)
axes[1].set_title("Tasa de cancelación por mes calendario")
axes[1].set_xlabel("Mes de llegada")
axes[1].set_ylabel("Reservas canceladas (%)")
axes[1].legend(title="Hotel")

for axis in axes:
    sns.despine(ax=axis)
    axis.grid(axis="x", alpha=0.25)
    axis.tick_params(axis="x", rotation=45)

figure.suptitle("Estacionalidad mensual de reservas y cancelaciones", fontsize=16)
figure.tight_layout()

if PROJECT_ROOT is not None:
    figures_dir = PROJECT_ROOT / "outputs" / "figures"
    figures_dir.mkdir(parents=True, exist_ok=True)
    seasonality_figure_path = figures_dir / "eda_monthly_seasonality.png"
    figure.savefig(seasonality_figure_path, dpi=300, bbox_inches="tight")
    print(f"Gráfica guardada en: {seasonality_figure_path}")

plt.show()
# Out:
# Gráfica guardada en: C:\Code\Vialesoft\Vialesoft_Devlab\Mini_Proyectos\Machine_Learning\Obligatorio2026\outputs\figures\eda_monthly_seasonality.png

# %% [markdown]
# ### Contraste con el año completo
#
# Se compara la tasa de todo el período disponible con la correspondiente a 2016. Una diferencia grande indicaría que el promedio mensual está condicionado por la cobertura parcial de 2015 y 2017 o por cambios entre años.

# %%
seasonality_2016_summary = (
    seasonality_df.loc[seasonality_df["ArrivalDateYear"].eq(2016)]
    .groupby(["CalendarMonth", "HotelType"], observed=True)
    .agg(
        reservations_2016=("IsCanceled", "size"),
        cancellation_rate_2016=("IsCanceled", "mean"),
    )
    .reset_index()
)

seasonality_sensitivity_summary = monthly_seasonality_summary.merge(
    seasonality_2016_summary,
    on=["CalendarMonth", "HotelType"],
    how="left",
)
seasonality_sensitivity_summary["cancellation_percentage_2016"] = (
    seasonality_sensitivity_summary["cancellation_rate_2016"] * 100
)
seasonality_sensitivity_summary["rate_difference_percentage_points"] = (
    seasonality_sensitivity_summary["cancellation_percentage"]
    - seasonality_sensitivity_summary["cancellation_percentage_2016"]
)
display(
    seasonality_sensitivity_summary[[
        "CalendarMonth", "HotelType", "observed_years",
        "cancellation_percentage", "cancellation_percentage_2016",
        "rate_difference_percentage_points",
    ]]
)
# Out:
#    CalendarMonth     HotelType  observed_years  cancellation_percentage  \
# 0        January    City Hotel               2                39.668094
# 1        January  Resort Hotel               2                14.819881
# 2       February    City Hotel               2                38.288016
# 3       February  Resort Hotel               2                25.620367
# 4          March    City Hotel               2                36.946423
# 5          March  Resort Hotel               2                22.871703
# 6          April    City Hotel               2                46.323529
# 7          April  Resort Hotel               2                29.343308
# 8            May    City Hotel               2                44.375607
# 9            May  Resort Hotel               2                28.772127
# 10          June    City Hotel               2                44.692171
# 11          June  Resort Hotel               2                33.070608
# 12          July    City Hotel               3                40.875371
# 13          July  Resort Hotel               3                31.401706
# 14        August    City Hotel               3                40.097963
# 15        August  Resort Hotel               3                33.449121
# 16     September    City Hotel               2                42.027027
# 17     September  Resort Hotel               2                32.368082
# 18       October    City Hotel               2                42.971729
# 19       October  Resort Hotel               2                27.510549
# 20      November    City Hotel               2                38.122561
# 21      November  Resort Hotel               2                18.916701
# 22      December    City Hotel               2                42.110358
# 23      December  Resort Hotel               2                23.829305
#
#     cancellation_percentage_2016  rate_difference_percentage_points
# 0                      32.111437                           7.556657
# 1                      13.461538                           1.358343
# 2                      39.223956                          -0.935940
# 3                      26.776316                          -1.155948
# 4                      36.375575                           0.570849
# 5                      20.753656                           2.118047
# 6                      43.218197                           3.105332
# 7                      27.959293                           1.384015
# 8                      39.064200                           5.311407
# 9                      26.581576                           2.190551
# 10                     43.843997                           0.848174
# 11                     27.465303                           5.605304
# 12                     33.312041                           7.563330
# 13                     31.644691                          -0.242986
# 14                     36.915335                           3.182628
# 15                     34.302671                          -0.853549
# 16                     40.480496                           1.546531
# 17                     29.875246                           2.492836
# 18                     46.148376                          -3.176647
# 19                     28.578629                          -1.068081
# 20                     43.561819                          -5.439258
# 21                     20.720721                          -1.804020
# 22                     43.260694                          -1.150336
# 23                     23.589001                           0.240304

# %% [markdown]
# Con menos de tres años completos no es posible afirmar que exista una tendencia estacional estable. Los resultados se interpretarán como patrones descriptivos del período observado y como una señal que deberá considerarse al diseñar la validación temporal, no como evidencia definitiva de un ciclo que se repetirá en años futuros.

# %% [markdown]
# ## Disponibilidad temporal y fugas de información
#
# El objetivo operativo propuesto es estimar el riesgo inmediatamente después de que la reserva sea confirmada y registrada. Una variable sólo puede utilizarse si su valor está disponible en ese momento. Las columnas que describen el desenlace o acumulan información posterior pueden generar métricas artificialmente altas y no estar disponibles al aplicar el modelo.

# %%
target_columns = ["IsCanceled"]
direct_leakage_columns = ["ReservationStatus", "ReservationStatusDate"]
post_booking_or_ambiguous_columns = [
    "AssignedRoomType", "BookingChanges"
]
confirmed_booking_candidate_columns = [
    column
    for column in bookings_df.columns
    if column not in [
        *target_columns,
        *direct_leakage_columns,
        *post_booking_or_ambiguous_columns,
    ]
]

availability_summary = pd.DataFrame(
    [
        {
            "classification": "Target",
            "columns": target_columns,
            "column_count": len(target_columns),
            "provisional_use": "Prediction objective; never used as an input.",
        },
        {
            "classification": "Direct leakage",
            "columns": direct_leakage_columns,
            "column_count": len(direct_leakage_columns),
            "provisional_use": "Exclude from every predictive feature set.",
        },
        {
            "classification": "Post-confirmation or temporally ambiguous",
            "columns": post_booking_or_ambiguous_columns,
            "column_count": len(post_booking_or_ambiguous_columns),
            "provisional_use": "Exclude from the confirmed-booking model; reconsider only for a defined later snapshot.",
        },
        {
            "classification": "Confirmed-booking candidates",
            "columns": confirmed_booking_candidate_columns,
            "column_count": len(confirmed_booking_candidate_columns),
            "provisional_use": "Carry into Feature Analysis; availability and usefulness still require validation.",
        },
    ]
)
display(availability_summary)
# Out:
#                               classification  \
# 0                                     Target
# 1                             Direct leakage
# 2  Post-confirmation or temporally ambiguous
# 3               Confirmed-booking candidates
#
#                                              columns  column_count  \
# 0                                       [IsCanceled]             1
# 1         [ReservationStatus, ReservationStatusDate]             2
# 2                 [AssignedRoomType, BookingChanges]             2
# 3  [HotelType, LeadTime, ArrivalDateYear, Arrival...            27
#
#                                      provisional_use
# 0      Prediction objective; never used as an input.
# 1         Exclude from every predictive feature set.
# 2  Exclude from the confirmed-booking model; reco...
# 3  Carry into Feature Analysis; availability and ...

# %% [markdown]
# ### Relación entre el estado final y el target
#
# `ReservationStatus` describe cómo terminó la reserva. Se comprueba si cada estado corresponde a un único valor de `IsCanceled`. Si esto ocurre, la columna revela directamente la respuesta que el modelo debería predecir.

# %%
reservation_status_target_table = pd.crosstab(
    bookings_df["ReservationStatus"],
    bookings_df["IsCanceled"],
    margins=True,
)
display(reservation_status_target_table)

reservation_status_summary = (
    bookings_df.groupby("ReservationStatus")
    .agg(
        rows=("IsCanceled", "size"),
        target_values=("IsCanceled", "nunique"),
        cancellation_rate=("IsCanceled", "mean"),
    )
    .reset_index()
)
reservation_status_summary["cancellation_percentage"] = (
    reservation_status_summary["cancellation_rate"] * 100
)
display(reservation_status_summary)
# Out:
# IsCanceled             0      1     All
# ReservationStatus
# Canceled               0  43017   43017
# Check-Out          75166      0   75166
# No-Show                0   1207    1207
# All                75166  44224  119390
#   ReservationStatus   rows  target_values  cancellation_rate  \
# 0          Canceled  43017              1                1.0
# 1         Check-Out  75166              1                0.0
# 2           No-Show   1207              1                1.0
#
#    cancellation_percentage
# 0                    100.0
# 1                      0.0
# 2                    100.0

# %% [markdown]
# ### Momento registrado por `ReservationStatusDate`
#
# La fecha del estado se compara con la llegada. Un valor anterior puede representar la fecha de cancelación; un valor posterior puede representar el cierre de una estadía. En ambos casos se genera como consecuencia de la evolución de la reserva y no es una característica disponible al crearla.

# %%
reservation_status_dates = pd.to_datetime(
    bookings_df["ReservationStatusDate"], errors="coerce"
)
days_from_status_to_arrival = (arrival_dates - reservation_status_dates).dt.days

print(f"Fechas de estado inválidas: {reservation_status_dates.isna().sum():,}")

status_date_timing_summary = (
    pd.DataFrame(
        {
            "ReservationStatus": bookings_df["ReservationStatus"],
            "DaysFromStatusToArrival": days_from_status_to_arrival,
        }
    )
    .groupby("ReservationStatus")["DaysFromStatusToArrival"]
    .agg(
        rows="size",
        minimum="min",
        median="median",
        maximum="max",
    )
    .reset_index()
)
display(status_date_timing_summary)

status_date_position_summary = pd.DataFrame(
    {
        "position_relative_to_arrival": [
            "Before arrival", "On arrival date", "After arrival"
        ],
        "rows": [
            days_from_status_to_arrival.gt(0).sum(),
            days_from_status_to_arrival.eq(0).sum(),
            days_from_status_to_arrival.lt(0).sum(),
        ],
    }
)
status_date_position_summary["percentage"] = (
    status_date_position_summary["rows"] / len(bookings_df) * 100
)
display(status_date_position_summary)
# Out:
# Fechas de estado inválidas: 0
#   ReservationStatus   rows  minimum  median  maximum
# 0          Canceled  43017        0    56.0      526
# 1         Check-Out  75166      -69    -3.0        0
# 2           No-Show   1207        0     0.0      111
#   position_relative_to_arrival   rows  percentage
# 0               Before arrival  42137   35.293576
# 1              On arrival date   2793    2.339392
# 2                After arrival  74460   62.367032

# %% [markdown]
# ### Variables dependientes del momento operativo
#
# `AssignedRoomType` y `BookingChanges` no describen necesariamente el estado de la reserva inmediatamente después de su confirmación. Su uso podría ser válido en un modelo ejecutado en una fecha posterior, pero exigiría definir un horizonte —por ejemplo, siete días antes de la llegada— y reconstruir el valor que cada variable tenía exactamente en ese momento. Como el dataset contiene sólo su valor final, se excluyen provisionalmente del escenario principal. En cambio, `DaysInWaitingList` avanza a Feature Analysis: la documentación original lo define como la cantidad de días que la reserva permaneció en espera antes de ser confirmada al cliente, por lo que ya es conocido al aplicar el modelo propuesto.

# %% [markdown]
# `ReservationStatus` y `ReservationStatusDate` se clasifican como fugas directas y no se utilizarán como predictores. Las variables temporalmente ambiguas también se excluyen del primer modelo serio. Las demás columnas avanzan como candidatas a Feature Analysis, lo que no implica todavía que sean útiles, estén correctamente codificadas o deban conservarse en el conjunto final.
